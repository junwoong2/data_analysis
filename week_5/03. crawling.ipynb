# %% [markdown]
# # 웹 크롤링(Web Crawling)
# - 복수 개의 웹페이지를 탐색하는 행위
# - 자동으로 웹페이지의 정보를 수집하는 일
# - 방식
#     - 시작 URL을 설정하고, HTML 코드를 분석하여 링크를 추출
#     - 추출된 링크를 따라 새로운 페이지를 요청하고, 이 과정을 반복
#     - 수집된 데이터를 저장하거나 처리

# %% [markdown]
# ## 웹 스크래핑(Web Scraping)
# - 특정 웹 페이지에서 필요한 데이터만을 추출하는 과정
# - 크롤링을 통해 수집한 정보를 분석해서 필요한 정보만 추출하는 일
# - 방식
#     - 수집된 HTML 문자열을 HTML 코드 형태로 변환
#     - 원하는 데이터를 추출하기 위한 HTML 요소에 접근할 수 있는 방법을 사용(예: CSS 선택자, XPath)
#     - 추출된 데이터를 정제하고 저장

# %% [markdown]
# ## 크롤링과 스크래핑의 차이점
#
# ||크롤링|스크래핑|
# |------|---|---|
# |목적|웹 페이지 탐색 및 수집|특정 데이터 추출|
# |범위|전체 웹|특정 웹 페이지|
# |데이터|링크, HTML|구체적인 내용(텍스트, 숫자 등)|

# %% [markdown]
# ## 웹 크롤링 주요 용도
# - 웹 크롤링은 다양한 분야에서 활용
# - 시장 연구, 경쟁사 분석, SNS 트랜드 파악 등 다양한 분야에서 크롤링을 황용해 데이터를 수집하고 분석하여 의사결정에 활용

# %% [markdown]
# ## 활용 사례
# - E-commerce 사이트에서의 가격 정보 수집
#     - 온라인 쇼핑몰에서는 상품의 가격 정보를 주기적으로 업데이트한다.
#     - 크롤링을 통해 이러한 가격 변동을 실시간으로 파악하고, 경쟁사의 가격 전략을 분석하는데 활용될 수 있다.
#     - 이는 마케팅 전략 수립에 있어 중요한 역할을 한다.
# - 소셜 미디어 데이터 분석을 위한 크롤링
#     - 소셜 미디어는 현재의 트렌드와 사회의 의견을 반영하는 중요한 공간이다.
#     - 특정 주제나 키워드에 대한 사람들의 반응을 파악하기 위해 크롤링을 통한 데이터 수집이 이루어진다.
#     - 이렇게 수집된 데이터는 다양한 분석 방법을 통해 유용한 인사이트를 제공한다.

# %% [markdown]
# ## 주요 크롤링 라이브러리
# - requests
#     - 파이썬 HTTP 통신에 사용되는 모듈
#     - 설치방법: `pip install requests`
# - beautifulsoup
#     - HTML, XML, JSON 등 파일의 구문을 분석하는 모듈
#     - 설치방법: `pip install beautifulsoup4`
# - selenium
#     - 웹 브라우저를 이용하는 자동화 프로그램입니다.
#     - 설치방법: `pip install selenium`

# %% [markdown]
# # HTML(Hyper Text Markup Language)
# - 웹 페이지에 필요한 구성요소를 구성하는 Markup 언어
# - 태그를 이용해 화면의 레이아웃 구조와 텍스트, 요소 등을 표현
#
#
# ```html
# <!DOCYTYPE HTML>
# <html>
#     <head>
#         <title>웹문서의 제목</title>
#         <meta charset="utf-8">
#     </head>
#
#     <body>
#         웹문서의 내용(실제 브라우저에 표시되는 내용)
#     </body>
# </html>
# ```

# %% [markdown]
# ### HTML Element
# - HTML 요소 또는 HTML 엘리먼트는 HTML 문서나 웹 페이지를 이루는 개별적인 요소를 의미
# - 태그에 이름을 지정하는 속성
#     - `id`
#         - 태그에 유일한 이름을 붙이고 싶을 때 사용
#         - `id` 속성의 값은 전체 페이지에서 단 하나의 요소에만 지정이 가능
#     - `class`
#         - 여러 태그에 동일한 이름을 붙이고 싶을 때 사용
#         - `class` 속성 값은 전체 페이지에서 여러 요소에 동일한 값으로 지정이 가능
#         - `id` 속성과는 달리 하나의 요소에 여러개의 `class` 이름을 지정할 수 있음

# %% [markdown]
# ![20240819_191408.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # CSS(Casading Style Sheet)
# - HTML 의 요소를 꾸며주는 스타일 시트
# - HTML 문서에 있는 요소들에 대하여 스타일을 적용
# - css 선택자를 이용하여 html 요소에 접근하여 스타일을 적용
# - css 선택자
#     - 태그명으로 접근하는 예시
#         - a 태그에 접근 : `a`
#     - 태그의 class 속성명으로 접근하는 예시
#         - class="btn" : `.btn`
#     - 태그의 id 속성명으로 접근하는 예시
#         - id="btn" : `#btn`
#
# - p 태그의 텍스트를 파란색으로 적용하는 예시
# ```CSS
# p {
#     color: blue;
# }
# ```

# %%
# %%html
# <!DOCTYPE html>
#
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>HTML & CSS 연습</title>
#
#         <style type="text/css">
#         /* 나는 css 주석 입니다. */
#
#         h2{
#             border-bottom: 3px solid #000;
#         }
#         .box{padding: 20px;border-bottom: 1px solid red;}
#
#         #css-doc-link{display: inline-block;border: 2px dotted blue;}
#
#         </style>
#
#     </head>
#
#     <body>
#         <!-- 나는 HTML 주석 입니다. -->
#
#         <!-- h 태그는 제목을 표시할 때 사용 하는 태그 h1 ~ h6 까지 있음 -->
#         <h1>나의 HTML 페이지</h1>
#         <h2>태그를 소개합니다.</h2>
#
#
#         <!-- div 태그는 레이아웃을 나누는데 주로 쓰이는 태그 -->
#         <div class="box">
#             <h3 style="color:blue">하이퍼링크만들기</h3>
#
#             <!-- a 태그는 링크를 걸어주는 태그 -->
#             <a href="https://naver.com" target="_blank">네이버로 이동하기</a><br>
#             <a href="https://www.google.com/" target="_blank">구글로 이동하기</a><br>
#         </div>
#
#         <div class="box">
#             <h3 class="mytitle">목록 만들기</h3>
#
#             <!-- ul 태그는 목록을 만드는 태그 -->
#             <ul>
#                 <li class="mylang">넘파이</li>
#                 <li class="mylang">판다스</li>
#                 <li class="mylang">사이킷런</li>
#                 <li class="mylang">파이토치</li>
#             </ul>
#         </div>
#
#         <div class="box">
#             <h3>이미지 랜더링</h3>
#
#             <!-- img 태그는 이미지를 삽입하는 태그 -->
#             <img src="https://blog.velsoft.com/wp-content/uploads/2018/10/HTML-Basic.jpg">
#             <br> <!-- 줄바꿈 태그 -->
#             <a id="css-doc-link" href="https://developer.mozilla.org/ko/docs/Web/CSS" target="_blank">
#                 <img src="https://miro.medium.com/v2/resize:fit:600/1*OFsc0SD55jhi8cjo7aCA4w.jpeg">
#             </a>
#         </div>
#
#         <div class="box">
#             <h3>문단 만들기</h3>
#
#             <!-- p 태그는 문단을 만드는 태그 -->
#             <p>
#                 기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br>
#                 인공지능의 한 분야로 간주된다. <br>
#                 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br>
#                 가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br>
#             </p>
#             <p>
#                 심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br>
#                 큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
#             </p>
#         </div>
#
#     </body>
# </html>
# Out:
# <!DOCTYPE html>
#
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>HTML & CSS 연습</title>
#
#         <style type="text/css">
#         /* 나는 css 주석 입니다. */
#
#         h2{
#             border-bottom: 3px solid #000;
#         }
#         .box{padding: 20px;border-bottom: 1px solid red;}
#
#         #css-doc-link{display: inline-block;border: 2px dotted blue;}
#
#         </style>
#
#     </head>
#
#     <body>
#         <!-- 나는 HTML 주석 입니다. -->
#
#         <!-- h 태그는 제목을 표시할 때 사용 하는 태그 h1 ~ h6 까지 있음 -->
#         <h1>나의 HTML 페이지</h1>
#         <h2>태그를 소개합니다.</h2>
#
#
#         <!-- div 태그는 레이아웃을 나누는데 주로 쓰이는 태그 -->
#         <div class="box">
#             <h3 style="color:blue">하이퍼링크만들기</h3>
#
#             <!-- a 태그는 링크를 걸어주는 태그 -->
#             <a href="https://naver.com" target="_blank">네이버로 이동하기</a><br>
#             <a href="https://www.google.com/" target="_blank">구글로 이동하기</a><br>
#         </div>
#
#         <div class="box">
#             <h3 class="mytitle">목록 만들기</h3>
#
#             <!-- ul 태그는 목록을 만드는 태그 -->
#             <ul>
#                 <li class="mylang">넘파이</li>
#                 <li class="mylang">판다스</li>
#                 <li class="mylang">사이킷런</li>
#                 <li class="mylang">파이토치</li>
#             </ul>
#         </div>
#
#         <div class="box">
#             <h3>이미지 랜더링</h3>
#
#             <!-- img 태그는 이미지를 삽입하는 태그 -->
#             <img src="https://blog.velsoft.com/wp-content/uploads/2018/10/HTML-Basic.jpg">
#             <br> <!-- 줄바꿈 태그 -->
#             <a id="css-doc-link" href="https://developer.mozilla.org/ko/docs/Web/CSS" target="_blank">
#                 <img src="https://miro.medium.com/v2/resize:fit:600/1*OFsc0SD55jhi8cjo7aCA4w.jpeg">
#             </a>
#         </div>
#
#         <div class="box">
#             <h3>문단 만들기</h3>
#
#             <!-- p 태그는 문단을 만드는 태그 -->
#             <p>
#                 기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br>
#                 인공지능의 한 분야로 간주된다. <br>
#                 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br>
#                 가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br>
#             </p>
#             <p>
#                 심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br>
#                 큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
#             </p>
#         </div>
#
#     </body>
# </html>

# %% [markdown]
# # Beautiful Soup
# - Beautiful Soup은 웹 페이지에서 정보를 쉽게 긁어낼 수 있게 해주는 라이브러리
# - Beautiful Soup은 파이썬의 웹 스크래핑 위한 라이브러리
# - 웹에서 가져온 HTML 문자열을 파이썬에서 사용하기 편하게 파싱해주는 라이브러리
#
# ```bash
# pip install beautifulsoup4
# ```

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4) (2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
html_str = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="UTF-8">
        <title>HTML & CSS 연습</title>
        <style type="text/css">
        /* 나는 css 주석 입니다. */
        h2{
            border-bottom: 3px solid #000;
        }
        .box{padding: 20px;border-bottom: 1px solid red;}
        #css-doc-link{display: inline-block;border: 2px dotted blue;}
        </style>
    </head>
    <body>
        <!-- 나는 HTML 주석 입니다. -->
        <!-- h 태그는 제목을 표시할 때 사용 하는 태그 h1 ~ h6 까지 있음 -->
        <h1>나의 HTML 페이지</h1>
        <h2>태그를 소개합니다.</h2>
        <!-- div 태그는 레이아웃을 나누는데 주로 쓰이는 태그 -->
        <div class="box">
            <h3 style="color:blue">하이퍼링크만들기</h3>
            <!-- a 태그는 링크를 걸어주는 태그 -->
            <a href="https://naver.com" target="_blank">네이버로 이동하기</a><br>
            <a href="https://www.google.com/" target="_blank">구글로 이동하기</a><br>
        </div>
        <div class="box">
            <h3 class="mytitle">목록 만들기</h3>
            <!-- ul 태그는 목록을 만드는 태그 -->
            <ul>
                <li class="mylang">넘파이</li>
                <li class="mylang">판다스</li>
                <li class="mylang">사이킷런</li>
                <li class="mylang">파이토치</li>
            </ul>
        </div>
        <div class="box">
            <h3>이미지 랜더링</h3>
            <!-- img 태그는 이미지를 삽입하는 태그 -->
            <img src="https://blog.velsoft.com/wp-content/uploads/2018/10/HTML-Basic.jpg">
            <br> <!-- 줄바꿈 태그 -->
            <a id="css-doc-link" href="https://developer.mozilla.org/ko/docs/Web/CSS" target="_blank">
                <img src="https://miro.medium.com/v2/resize:fit:600/1*OFsc0SD55jhi8cjo7aCA4w.jpeg">
            </a>
        </div>
        <div class="box">
            <h3>문단 만들기</h3>
            <!--p 태그는 문단을 만드는 태그 -->
            <p>
                기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br>
                인공지능의 한 분야로 간주된다. <br>
                컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br>
                가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br>
            </p>
            <p>
                심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br>
                큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
            </p>
        </div>

    </body>
</html>"""

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## html 객체 형태로 변환

# %%
soup = BeautifulSoup(html_str, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>HTML &amp; CSS 연습</title>
# <style type="text/css">
#         /* 나는 css 주석 입니다. */
#
#         h2{
#             border-bottom: 3px solid #000;
#         }
#         .box{padding: 20px;border-bottom: 1px solid red;}
#
#         #css-doc-link{display: inline-block;border: 2px dotted blue;}
#
#         </style>
# </head>
# <body>
# <!-- 나는 HTML 주석 입니다. -->
# <!-- h 태그는 제목을 표시할 때 사용 하는 태그 h1 ~ h6 까지 있음 -->
# <h1>나의 HTML 페이지</h1>
# <h2>태그를 소개합니다.</h2>
# <!-- div 태그는 레이아웃을 나누는데 주로 쓰이는 태그 -->
# <div class="box">
# <h3 style="color:blue">하이퍼링크만들기</h3>
# <!-- a 태그는 링크를 걸어주는 태그 -->
# <a href="https://naver.com" target="_blank">네이버로 이동하기</a><br/>
# <a href="https://www.google.com/" target="_blank">구글로 이동하기</a><br/>
# </div>
# <div class="box">
# <h3 class="mytitle">목록 만들기</h3>
# <!-- ul 태그는 목록을 만드는 태그 -->
# <ul>
# <li class="mylang">넘파이</li>
# <li class="mylang">판다스</li>
# <li class="mylang">사이킷런</li>
# <li class="mylang">파이토치</li>
# </ul>
# </div>
# <div class="box">
# <h3>이미지 랜더링</h3>
# <!-- img 태그는 이미지를 삽입하는 태그 -->
# <img src="https://blog.velsoft.com/wp-content/uploads/2018/10/HTML-Basic.jpg"/>
# <br/> <!-- 줄바꿈 태그 -->
# <a href="https://developer.mozilla.org/ko/docs/Web/CSS" id="css-doc-link" target="_blank">
# <img src="https://miro.medium.com/v2/resize:fit:600/1*OFsc0SD55jhi8cjo7aCA4w.jpeg"/>
# </a>
# </div>
# <div class="box">
# <h3>문단 만들기</h3>
# <!-- p 태그는 문단을 만드는 태그 -->
# <p>
#                 기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br/>
#                 인공지능의 한 분야로 간주된다. <br/>
#                 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br/>
#                 가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br/>
# </p>
# <p>
#                 심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br/>
#                 큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
#             </p>
# </div>
# </body>
# </html>

# %% [markdown]
# ## 태그명을 이용해서 접근
# - 엘리먼트의 속성과 값을 이용해서 접근도 가능

# %% [markdown]
# ### find 메서드
# - 한 개의 엘리먼트만 찾기
#     - `find("태그명", "속성과 값을 담은 딕셔너리")`

# %%
soup.find_all("p")
# Out:
# [<p>
#                  기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br/>
#                  인공지능의 한 분야로 간주된다. <br/>
#                  컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br/>
#                  가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br/>
#  </p>,
#  <p>
#                  심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br/>
#                  큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
#              </p>]

# %% [markdown]
# ### find_all 메서드
# - 여러 개의 엘리먼트 찾기
#     - `find_all("태그명", "속성과 값을 담은 딕셔너리")`

# %% [markdown]
# ## css 선택자(selector)를 이용해서 접근

# %% [markdown]
# ### select_one 메서드
# - css 선택자를 통해 하나의 엘리먼트 선택

# %%
tmp = {"target": "_black"}
soup.findAll("a", tmp)
tmp
# Out:
# {'target': '_black'}

# %% [markdown]
# ### select 메서드
# - css 선택자를 통해 여러 개의 엘리먼트 선택

# %%
soup.select("body p")
# Out:
# [<p>
#                  기계 학습 또는 머신 러닝은 경험을 통해 자동으로 개선하는 컴퓨터 알고리즘의 연구이다.<br/>
#                  인공지능의 한 분야로 간주된다. <br/>
#                  컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야이다. <br/>
#                  가령, 기계 학습을 통해서 수신한 이메일이 스팸인지 아닌지를 구분할 수 있도록 훈련할 수 있다.<br/>
#  </p>,
#  <p>
#                  심층 학습 또는 딥 러닝은 여러 비선형 변환기법의 조합을 통해 높은 수준의 추상화를 시도하는 기계 학습 알고리즘의 집합으로 정의되며,<br/>
#                  큰 틀에서 사람의 사고방식을 컴퓨터에게 가르치는 기계학습의 한 분야라고 이야기할 수 있다.
#              </p>]

# %%
import requests

# %%
url = "http://www.bobaedream.co.kr/"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.encoding
# Out:
# 'ISO-8859-1'

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <title>ë³´ë°°ëë¦¼ - ì¤ê³ ì°¨ íë«í¼, ììì°¨, ììì¤ê³ ì°¨ ë° ì¤ê³ ì°¨ìì¸, ë´ì°¨ìì¸ ì ê³µ</title>
# <meta name="description" content="ì¤ê³ ì°¨, ì»¤ë®¤ëí°, ììì°¨, ì¸ì ì°¨, ììì¤ê³ ì°¨, ì¤í¬ì¸ ì¹´, íëì¹´ ì ë¬¸ ì¤ê³ ì°¨ì¼íëª°. ì¤ê³ ìëì°¨, ìí¼ì¹´, ì¬ëì¹´, ìº íì¹´ íë¬¼ì°¨, í¹ì¥ì°¨, í½ìí¸ë­ ë§¤ë§¤ ë° íë§¤, ì¤ê³ ì°¨ìì¸ ì ê³µ, êµ­ë´ ìµë ìëì°¨ ì»¤ë®¤ëí°">
# <meta name="keywords" content="ì¤ê³ ì°¨, ì¤ê³ ì°¨ìì¸, êµ­ì°ì¤ê³ ì°¨, ììì¤ê³ ì°¨, ë´ì°¨íê¸°">
# <meta name="viewport" content="user-scalable=yes"/>
# <meta property="og:title" content="ë³´ë°°ëë¦¼ - ì¤ê³ ì°¨ íë«í¼, ììì°¨, ììì¤ê³ ì°¨ ë° ì¤ê³ ì°¨ìì¸, ë´ì°¨ìì¸ ì ê³µ">
# <meta property="og:url" content="https://www.bobaedream.co.kr/">
# <meta property="og:image" content="http://image.bobaedream.co.kr/renew2017/assets/images/bobae.png">
# <meta property="og:description" content="ì¤ê³ ì°¨, ì¤ê³ ìëì°¨, ììì°¨, ì¸ì ì°¨, íëì¹´, ì¤í¬ì¸ ì¹´ ë§¤ë§¤ ë° íë§¤, ì¤ê³ ì°¨ìì¸ ì ê³µ">
# <link rel="shortcut icon" type="image/x-icon" href="//image.bobaedream.co.kr/renew2017/assets/images/favicon.ico">
# <link rel="canonical" href="https://www.bobaedream.co.kr" />
# <link rel="stylesheet" type="text/css" href="//image.bobaedream.co.kr/renew2017/assets/css/bobae.common.css?v=221126">
# <link rel="stylesheet" type="text/css" href="//image.bobaedream.co.kr/renew2017/assets/css/bobae.main.css?v=230131">
# <meta name="google-site-verification" content="ZVLCoZsfyrDkP9ywzHzyG4bepKZA1igTczFieiLB-dA" />
# <meta name="referrer" content="no-referrer-when-downgrade">
# </head>
# <body>
# <div id="skip-nav">
#     <ul>
#         <li><a href="#bobaeGNB">ì£¼ìë©ë´ë¡ ë°ë¡ê°ê¸°</a></li>
#         <li><a href="#bobaeMain">ì¤ëì ìëì°¨ ë°ë¡ê°ê¸°</a></li>
#         <li><a href="#bobaeFoot">íë¨ì ë³´ë¡ ë°ë¡ê°ê¸°</a></li>
#     </ul>
# </div>
# <!-- bobaeHead -->
# <div id="bobaeHead" class="bobae-header-v3 js-header">
#     <!-- gnb-util -->
#     <div class="top-container">
#         <div class="component">
#             <h1 class="top-logo-wrapper">
#                 <a class="link" href="https://www.bobaedream.co.kr" title="ë³´ë°°ëë¦¼">
#                     <span class="icon-symbol-car"></span>
#                     <span class="icon-logo">ë³´ë°°ëë¦¼</span>
#                 </a>
#                 <a class="link subtext" href="https://www.bobaedream.co.kr" title="êµ­ë´ 1ì ìëì°¨ì¼íëª°">
#                     <span class="icon-subtext">êµ­ë´ 1ì ìëì°¨ì¼íëª°</span>
#                 </a>
#             </h1>
#             <div class="top-util-wrapper">
#             		<div class="text-util-wrapper">
# <script language="javascript">
# ctmp = document.cookie.split(";");
# var popup_url_ok = "/popup/main_pop_220131.html";
# var popchk = "yes";
# var todayDate = new Date();
# var strTemp = "" + todayDate.getFullYear() + "" + ((todayDate.getMonth()+1) < 10 ? "0" + (todayDate.getMonth()+1) : (todayDate.getMonth()+1)) + (todayDate.getDate() < 10 ? "0" + todayDate.getDate() : todayDate.getDate()) + (todayDate.getHours() < 10 ? "0" + todayDate.getHours() : todayDate.getHours());
#
# for (i = 0; i < ctmp.length; i++) {
# 	if (ctmp[i].match("bobaedream_popup_220131")) {
# 		popchk = "no";
# 	}
# }
#
#
# if (popchk == "yes" && popup_url_ok && ("2022013109" <= strTemp && "2022020218" > strTemp)) {
# 	window.open("/popup/main_pop_220131.html", "bobaedream_popup_220131", "width=500,height=538, top=24,left=0,toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=no,copyhistory=no");
# }
#   var chkLogin = "no";
#   for (i = 0; i < ctmp.length; i++) {
#     if (ctmp[i].match("Member_ID")) {
#       cctmp = ctmp[i].split("=");
#       if (cctmp[1] != "") {
#         chkLogin = "yes";
#       }
#     }
#   }
#
# document.write("<ul class=\"text-util-list\">");
#
# 				/* ë¡ê·¸ì¸í */
# if (chkLogin == "yes") {
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/member/logout.php\" class=\"link\"><span class=\"text\">ë¡ê·¸ìì</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://security.bobaedream.co.kr/member/join/join_user_data_edit.php\" class=\"link\"><span class=\"text\">ëìì ë³´</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/mycar/manage/mycar_manage_main.php\" class=\"link\"><span class=\"text\">ë§¤ë¬¼ê´ë¦¬</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/center/car_photo_self.php?send_type=1\"><span class=\"text\">ì¬ì´ë²ë§¤ì¥ ì°¨ëë±ë¡</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/center/center.htm\" class=\"link\"><span class=\"text\">ê³ ê°ì¼í°</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/mycommunity?lo=10&or_where=answer&globaltop=y\" class=\"link\"><span class=\"i-text\"><span class=\"icon-mypage\"></span><span class=\"text\">ë§ì´íì´ì§</span></span></a></li>");
#   } else {
# 				/* ë¡ê·¸ì¸ì  */
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://security.bobaedream.co.kr/member/slogin.php\" class=\"link\"><span class=\"text\">ë¡ê·¸ì¸</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://security.bobaedream.co.kr/member/join/register_choice_renew.php\" class=\"link\"><span class=\"text\">íìê°ì</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/center/car_photo_self.php?send_type=1\"><span class=\"text\">ì¬ì´ë²ë§¤ì¥ ì°¨ëë±ë¡</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/center/center.htm\" class=\"link\"><span class=\"text\">ê³ ê°ì¼í°</span></a></li>");
# 				document.write("<li class=\"text-util-item\"><a class=\"text-util\" href=\"https://www.bobaedream.co.kr/mycommunity?lo=10&or_where=answer&globaltop=y\" class=\"link\"><span class=\"i-text\"><span class=\"icon-mypage\"></span><span class=\"text\">ë§ì´íì´ì§</span></span></a></li>");
# 	}
#
# document.write("</ul>");
# </script>
#             </div>
#             <div class="user-util-wrapper">
#                 <ul class="user-util-list">
# <script language="javascript">
# if (chkLogin == "yes") document.write("<li class=\"user-util-item\"><button onclick=\"getnoti();\" type=\"button\" class=\"my-util js-svc-tab\"><span class=\"icon-util-alarm\"></span><span class=\"count\"><em class=\"text\" id=\"noti\">0</em></span></button><div class=\"svc-noti svc-panel js-svc-panel\" id=\"svc-noti\"></div></li>");
# </script>
#                     <li class="user-util-item">
#                         <a href="https://www.bobaedream.co.kr/mycar/manage/mycar_recent.php" class="my-util">
#                             <span class="icon-util-history"></span>
#                         </a>
#                     </li>
#                     <li class="user-util-item">
#                         <a href="https://www.bobaedream.co.kr/mycar/manage/mycar_select_list.php" class="my-util">
#                             <span class="icon-util-like"></span>
#                         </a>
#                     </li>
#                 </ul>
#             </div>
#             <div class="top-service-banner">
#                 <a class="link" target="_blank" href="https://www.bobaedream.co.kr/mycar/mycar_photo_request.php?mType=D" title="ì¬ì´ë²ë§¤ì¥ ê´ê³ ì ì²­ 02-784-2329">
#                     <span class="banner">ì¬ì´ë²ë§¤ì¥ ê´ê³ ì ì²­ 02-784-2329</span>
#                 </a>
#             </div>
#             </div>
#         </div>
#     </div>
#     <div class="gnb-container">
#        <div class="component">
#             <div class="gnb-menu-wrapper">
#                 <ul class="gnb-menu-list js-menu">
#                     <li class="gnb-menu-item js-menu-item cyber">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/cyber/CyberCar.php?sel_m_gubun=ALL">
#                             <span class="icon-menu-cyber">ì¬ì´ë²ë§¤ì¥</span>
#                         </a>
#                         <div class="sub-menu multiple js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                             <li class="sub-menu-item"><a href="/cyber/CyberCar.php?sel_m_gubun=ALL">ì ì²´ë§¤ë¬¼</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?gubun=K">êµ­ì°ì°¨ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?gubun=I">ììì°¨ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?cat=1">ì¹ì©ì°¨ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?cat=2">ì¤í¬ì¸ ì¹´ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?cat=4">SUVÂ·ì§íë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?cat=3">ë°´Â·RVÂ·ë²ì¤ë§¤ì¥</a></li>
# 									</ul>
#                                  </div>
#                                  <div class="sub-menu-inner">
#                                      <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=pick">í½ìÂ·í¸ë­ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=camp">ìº íì¹´ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=tuning">íëì¹´ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=old">ì¬ëì¹´Â·í´ëìë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=super">ìí¼ì¹´ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=rare">í¬ê·ì°¨ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="/cyber/CyberCar.php?features=auto">ì¤í ê°¤ë¬ë¦¬ë§¤ì¥</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item domestic">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/mycar/mycar_list.php?gubun=K">
#                             <span class="icon-menu-domestic">êµ­ì°ì°¨</span>
#                         </a>
#                         <div class="sub-menu js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?gubun=K">êµ­ì°ì°¨ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?sel_m_gubun=tuning_K">íëì¹´ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?sel_m_gubun=succ_K">ë¦¬ì¤ë í¸ì°¨ë</a></li>
#                                         <li class="sub-menu-item"><a href="https://www.bobaedream.co.kr/cyber/CyberCar.php?gubun=K">ì¬ì´ë²ë§¤ì¥</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item imported">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/mycar/mycar_list.php?gubun=I">
#                             <span class="icon-menu-imported">ììì°¨</span>
#                         </a>
#                         <div class="sub-menu js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?gubun=I">ììì°¨ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?sel_m_gubun=tuning_I">íëì¹´ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_list.php?sel_m_gubun=succ_I">ë¦¬ì¤ë í¸ì°¨ë</a></li>
#                                         <li class="sub-menu-item"><a href="https://www.bobaedream.co.kr/cyber/CyberCar.php?gubun=I">ì¬ì´ë²ë§¤ì¥</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item tuning">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/cyber/CyberCar.php?features=tuning">
#                             <span class="icon-menu-tuning">íëì¹´</span>
# 							<span class="icon-hot">ì¸ê¸°</span>
#                         </a>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item price">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/dealguide/market_price_new.php">
#                             <span class="icon-menu-domestic">ì¤ê³ ì°¨ìì¸</span>
#                         </a>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item community">
#                          <a class="gnb-menu" href="https://www.bobaedream.co.kr/board/bbs.php">
#                              <span class="icon-menu-community">ì»¤ë®¤ëí°</span>
#                          </a>
#                          <div class="sub-menu multiple js-sub-menu">
#                              <div class="sub-menu-wrapper">
#                                  <div class="sub-menu-inner">
#                                      <a href="/board/bbs.php" class="title">ê²ìí</a>
#                                      <ul class="sub-menu-list">
#                                          <li class="sub-menu-item"><a href="/list?code=best">ë² ì¤í¸ê¸</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=freeb">ìì ê²ìí</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=politic">ì ì¹ê²ìí</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=battle">ìì¹ê¸°Â·ë°°íÂ·ëª©ê²©ë´</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=famous">ì ëªì¸ì ì°¨</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=nnews">ìëì°¨ë´ì¤</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=bbstory">ë³´ë°°ëë¦¼ ì´ì¼ê¸°</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=bb_talk">ì ìÂ·ê±´ì</a></li>
#                                          <li class="sub-menu-item"><a href="/event/event_list.php?event_gubun=1">ì´ë²¤í¸</a></li>
#                                      </ul>
#                                  </div>
#                                  <div class="sub-menu-inner">
#                                      <a href="/board/data.php" class="title">ìë£ì¤</a>
#                                      <ul class="sub-menu-list">
#                                          <li class="sub-menu-item"><a href="/list?code=strange">ì ë¨¸ê²ìí</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=accident">êµíµì¬ê³ Â·ë¸ë°</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=national">êµ­ì°ì°¨ê²ìí</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=import">ììì°¨ê²ìí</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=hotcar">ë´ì°¨ì¬ì§</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=dica">ì§ì°Â·í¹ì¢ë°ê²¬</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=special">ìëì°¨ì¬ì§Â·ëìì</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=wheel">ì¥ì°©ìê³µì¬ì§</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=music">ìì ì¬ì§Â·ëìì</a></li>
#                                      </ul>
#                                  </div>
#                                  <div class="sub-menu-inner">
#                                      <a href="/board/data.php" class="title">&nbsp;</a>
#                                      <ul class="sub-menu-list">
#                                          <li class="sub-menu-item"><a href="/list?code=girl">ë ì´ì±ëª¨ë¸</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=army">êµ°ì¬Â·ë¬´ê¸°</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=truck">í¸ë­Â·ë²ì¤Â·ì¤ê¸°</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=skybr">í­ê³µÂ·í´ì´Â·ì² ë</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=bike">ì¤í ë°ì´Â·ìì ê±°</a></li>
#                                          <li class="sub-menu-item"><a href="/list?code=vi">ì¬ëì¹´Â·ì¶ìµê±°ë¦¬</a></li>
#                                      </ul>
#                                  </div>
#                              </div>
#                          </div>
#                      </li>
#                     <li class="gnb-menu-item js-menu-item mycar">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/mycar/mycar.php">
#                             <span class="icon-menu-mycar">ë´ì°¨íê¸°</span>
#                         </a>
#                         <div class="sub-menu js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="/mycar/mycar.php">ë´ì°¨íê¸° í</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_self_step1.php?gubun=K">êµ­ì°ì°¨ ìíë±ë¡</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_self_step1.php?gubun=I">ììì°¨ ìíë±ë¡</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_photo_request.php?mType=C">ì¬ì´ë²ë§¤ì¥ë±ë¡</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/ticket.php?gubun=K">êµ­ì°ì°¨ ë§¤ë¬¼ë±ë¡ê¶</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/ticket.php?gubun=I">ììì°¨ ë§¤ë¬¼ë±ë¡ê¶</a></li>
#                                         <li class="sub-menu-item"><a href="/mycar/mycar_photo_request.php?mType=D">ì´¬ìëíìë¹ì¤</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item motorcycle">
#                         <a class="gnb-menu" href="https://bike.bobaedream.co.kr/">
#                             <span class="icon-menu-motorcycle">ì¤í ë°ì´</span>
#                         </a>
#                         <div class="sub-menu js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr">ì¤í ë°ì´í</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike2/bike_list.php?ifnew=Y">ì ì°¨ ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike2/bike_list.php?ifnew=N">ì¤ê³ ì°¨ ë§¤ì¥</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike_good/bike_good_list.php">ì©íì¥í°</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike2/board/bike_community_main.php">ì»¤ë®¤ëí°</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike2/bike_apply.php">ë§¤ë¬¼ë±ë¡íê¸°</a></li>
#                                         <li class="sub-menu-item"><a href="https://bike.bobaedream.co.kr/bike2/mycar_list_main.php">ëìë§¤ë¬¼ê´ë¦¬</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item market">
#                         <a class="gnb-menu" href="https://good.bobaedream.co.kr/good/list_sale.php">
#                             <span class="icon-menu-market">ì¤ê³ ì¥í°</span>
#                         </a>
#                         <div class="sub-menu js-sub-menu">
#                             <div class="sub-menu-wrapper">
#                                 <div class="sub-menu-inner">
#                                     <ul class="sub-menu-list">
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/list_sale.php">ì ì²´ë³´ê¸°</a></li>
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/list_sale.php?on=old">ì¤ê³ ì©í ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/list_sale.php?on=new">ìì í ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/list_sale.php?d1=150">ììì°¨ì©í ê²ì</a></li>
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/home.php">ì©íë±ë¡íê¸°</a></li>
#                                         <li class="sub-menu-item"><a href="https://good.bobaedream.co.kr/good/list_mygood.php">ëì ì©íê´ë¦¬</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </li>
#                     <li class="gnb-menu-item js-menu-item store">
#                         <a class="gnb-menu" href="https://www.bobaedream.co.kr/partner/partner_main.php">
#                             <span class="icon-menu-store">ìì²´ê²ì</span>
#                         </a>
#                     </li>
#                     <!--
#                     <li class="gnb-menu-item js-menu-item">
#                         <button class="btn-navigation" type="button">
#                             <span class="icon-menu-more">ëë³´ê¸°</span>
#                             <span class="icon-arrow"></span>
#                         </button>
#                     </li>
#                     -->
#                 </ul>
#             </div>
# <script type="text/javascript" src="//image.bobaedream.co.kr/renew2017/assets/js/bobae.min.js?v=3"></script>
#             <div class="square-util-wrapper">
#                 <ul class="square-util-list">
#                     <li class="square-util-item">
#                         <button class="square-util btn-search js-btn-srch" type="button">
#                             <span class="icon-util-search">ê²ìíê¸°</span>
#                         </button>
#                         <div class="field-search js-top-srch">
#                             <form name="search_form" method="post" action="//www.bobaedream.co.kr/search" onsubmit="javascript:	if(!document.search_form.keyword.value) { var _this = BOBAE.header; _this.$topSrch.parent('li').removeClass('is-extend'); return false; } else { document.search_form.submit(); }">
#                                 <label for="keyword" class="blind">ê²ìíê¸°</label>
#                                 <span class="inp-srch">
#                                     <input type="search" id="keyword" name="keyword">
#                                 </span>
#                                 <button class="btn-submit" type="submit">
#                                     <span class="icon-util-search">ê²ìíê¸°</span>
#                                 </button>
#                             </form>
#                         </div>
#                     </li>
#                     <li class="square-util-item">
#                         <button class="square-util js-btn-allsvc" type="button">
#                             <span class="icon-util-menu">ì ì²´ë©ë´</span>
#                         </button>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </div>
# </div>
# <!-- // bobaeHead -->
#
# <!-- bobaeService -->
# <div class="bobae-service js-all-service" id="bobaeService">
#     <div class="bs-dim js-bs-dim"></div>
#     <div class="svc-box">
#         <h2 class="blind">ë³´ë°°ëë¦¼ ì ì²´ë©ë´</h2>
#         <!-- [S] service-all-area -->
#         <div class="service-all-area">
#             <div class="svc-col">
#                 <h3 class="stit"><a href="https://www.bobaedream.co.kr/cyber/CyberCar.php?sel_m_gubun=ALL">ì¬ì´ë²ë§¤ì¥</a></h3>
#                 <ul class="svc-list">
#                     <li><a href="/cyber/CyberCar.php?gubun=K">êµ­ì°ì°¨ë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?gubun=I">ììì°¨ë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?cat=1">ì¹ì©ì°¨ë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?cat=2">ì¤í¬ì¸ ì¹´ë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?cat=4">SUVÂ·ì§íë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?cat=3">ë°´Â·RVÂ·ë²ì¤ë§¤ì¥</a></li>
#                     <li><a href="/cyber/CyberCar.php?features=camp">ìº íì¹´ë§¤ì¥</a></li>
#                     <li><a href="/list?code=bbstory">ë³´ë°°ëë¦¼ ì´ì¼ê¸°</a></li>
#                     <li><a href="/list?code=bb_talk">ì ìÂ·ê±´ì</a></li>
#                     <li><a href="/event/event_list.php?event_gubun=1">ì´ë²¤í¸</a></li>
#                 </ul>
#             </div>
#             <div class="svc-col">
#                 <h3 class="stit"><a href="/board/data.php">ìë£ì¤</a></h3>
#                 <ul class="svc-list">
#                     <li><a href="/list?code=strange">ì ë¨¸ê²ìí</a></li>
#                     <li><a href="/list?code=accident">êµíµì¬ê³ Â·ë¸ë°</a></li>
#                     <li><a href="/list?code=national">êµ­ì°ì°¨ê²ìí</a></li>
#                     <li><a href="/list?code=import">ììì°¨ê²ìí</a></li>
#                     <li><a href="/list?code=hotcar">ë´ì°¨ì¬ì§</a></li>
#                     <li><a href="/list?code=dica">ì§ì°Â·í¹ì¢ë°ê²¬</a></li>
#                     <li><a href="/list?code=special">ìëì°¨ì¬ì§Â·ëìì</a></li>
#                     <li><a href="/list?code=wheel">ì¥ì°©ìê³µì¬ì§</a></li>
#                     <li><a href="/list?code=music">ìì ì¬ì§Â·ëìì</a></li>
#                     <li><a href="/list?code=girl">ë ì´ì±ëª¨ë¸</a></li>
#                     <li><a href="/list?code=army">êµ°ì¬Â·ë¬´ê¸°</a></li>
#                     <li><a href="/list?code=truck">í¸ë­Â·ë²ì¤Â·ì¤ê¸°</a></li>
#                     <li><a href="/list?code=skybr">í­ê³µÂ·í´ì´Â·ì² ë</a></li>
#                     <li><a href="/list?code=bike">ì¤í ë°ì´Â·ìì ê±°</a></li>
#                     <li><a href="/list?code=vi">ì¬ëì¹´Â·ì¶ìµê±°ë¦¬</a></li>
#                 </ul>
#             </div>
#             <div class="svc-col">
#                 <h3 class="stit"><a href="/">íë§ë³</a></h3>
#                 <ul class="svc-list">
#                     <li><a href="/event/event_list.php?event_gubun=1">ë³´ë°°ëë¦¼ ì´ë²¤í¸</a></li>
#                 </ul>
#             </div>
#         </div>
#         <!-- //[E] service-all-area -->
#     </div>
# </div>
# <!-- //bobaeService -->
#
# <!-- bobaeMain -->
# <div id="bobaeMain" class="main-container">
#
#     <div class="component">
#
#         <!-- [S] Main Left Contents -->
#         <div class="main-content">
#             <div class="main-section special">
#                 <div class="list-wrapper">
#                     <ul class="product-list" id="special-spot"></ul>
#                 </div>
#             </div>
#
# 						<!-- [D] 2019-04-01 ì¶ê° -->
#             <div class="main-cyber-ad">
#                 <div class="content-area">
#                     <p class="text">
#                         ì¬ì´ë²ë§¤ì¥ì ì°¨ëì ë±ë¡íë©´ ë´ì°¨ë¥¼ ê°ì¥ ë¹¨ë¦¬ ì  ê° ë°ê³  í ì ììµëë¤.
#                     </p>
#                 </div>
#                 <div class="contact-area">
#                     <span class="text">
#                         ì°¨ëê´ê³  ì ì²­/ìë´ì í <em>02-784-2329</em>
#                     </span>
#                     <a class="link" target="_blank" title="ì¸í°ë·ì¼ë¡ ì ì²­íê¸°" href="/mycar/mycar_photo_request.php?mType=D">
#                         <span class="link-text">ì¸í°ë·ì¼ë¡ ì ì²­íê¸°</span>
#                     </a>
#                 </div>
#             </div>
#             <!-- //[D] 2019-04-01 ì¶ê° ë -->
#
#             <div class="main-section best">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-best">ì¬ì´ë²ë§¤ì¥ ë² ì¤í¸ì¹´</span>
#                     </h2>
#                 </div>
#                 <div class="list-wrapper">
#                     <ul class="product-list" id="cntprd">
#                     </ul>
#                     <div class="main-view-more">
#                         <a class="btn-more" href="https://www.bobaedream.co.kr/cyber/CyberCar.php?sel_m_gubun=ALL">
#                             <span class="text">ëë³´ê¸°</span>
#                         </a>
#                     </div>
#                 </div>
#             </div>
#             <div class="main-section rare">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-rare">ë³´ë°°ììë§ ë³¼ ì ìë í¬ê·ì°¨</span>
#                     </h2>
#                 </div>
#                 <div class="main-hashtag">
#                     <ul class="hashtag-list">
#                         <li class="hashtag-item is-selected">
#                             <a class="hashtag" href="javascript:Product('R','0');">
#                                 <span class="text">í¬ìì°¨ë</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('S',1);">
#                                 <span class="text">ìí¼ì¹´</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('T',2);">
#                                 <span class="text">íëì¹´</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('O',3);">
#                                 <span class="text">ì¬ëì¹´</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('C',4);">
#                                 <span class="text">ìº íì¹´</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('P',5);">
#                                 <span class="text">í½ìí¸ë­</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('H',6);">
#                                 <span class="text">ì¤í¬ì¸ ì¹´</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('I',7);">
#                                 <span class="text">ììì°¨</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('M',8);">
#                                 <span class="text">ëìì</span>
#                             </a>
#                         </li>
#                         <li class="hashtag-item">
#                             <a class="hashtag" href="javascript:Product('A',9);">
#                                 <span class="text">ì¤í ê°¤ë¬ë¦¬</span>
#                             </a>
#                         </li>
#                     </ul>
#                 </div>
#                 <div class="list-wrapper">
#                     <ul class="product-list" id="product-spot">
#                     </ul>
#                 </div>
#             </div>
#         </div>
#         <!-- // [E] Main Left Contents -->
#         <!-- [S] Main right Contents -->
#         <div class="main-aside">
#             <div class="side-section community">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-community">ì»¤ë®¤ëí° ë² ì¤í¸</span>
#                     </h2>
#                     <a class="link" href="https://www.bobaedream.co.kr/list?code=best" title="ì»¤ë®¤ëí° ë² ì¤í¸ê¸ ëë³´ê¸°">
#                         <span class="text">ëë³´ê¸°</span>
#                     </a>
#                 </div>
#                 <div class="community-content">
#                     <div class="community-tabs js-indicator-tabs">
#                         <ul class="tab-list">
#                             <li class="tab-item is-selected">
#                                 <button type="button" class="tab" onclick="Communibest('1_10');">
#                                     <span class="text">1~10ì</span>
#                                 </button>
#                             </li>
#                             <li class="tab-item">
#                                 <button type="button" class="tab" onclick="Communibest('11_20');">
#                                     <span class="text">11~20ì</span>
#                                 </button>
#                             </li>
#                             <li class="tab-item">
#                                 <button type="button" class="tab" onclick="Communibest('yesterday');">
#                                     <span class="text">ì´ì </span>
#                                 </button>
#                             </li>
#                             <li class="tab-item">
#                                 <button type="button" class="tab" onclick="Communibest('week');">
#                                     <span class="text">ì£¼ê°</span>
#                                 </button>
#                             </li>
#                             <li class="tab-item">
#                                 <button type="button" class="tab" onclick="Communibest('comm');">
#                                     <span class="text">ëê¸ì</span>
#                                 </button>
#                             </li>
#                         </ul>
#                         <div class="indicator js-indicator"></div>
#                     </div>
#                     <ul class="community-list" id="Communibest">
#                     </ul>
#                 </div>
#             </div>
#
#             <div class="side-section news">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-news">ìëì°¨ ë´ì¤</span>
#                     </h2>
#                     <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews" title="ìëì°¨ë´ì¤ ëë³´ê¸°">
#                         <span class="text">ëë³´ê¸°</span>
#                     </a>
#                 </div>
#                 <div class="news-content">
#
#                     <div class="hot-news">
#                         <div class="image">
#                             <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews" title="ì¤ë§í¸í°ê³¼ ì°¨ëì ê²½ê³ìì´<br>ì¼ì±ì ìÂ·íëì°¨ ìì¡ìë¤">
#                                 <img src="//file1.bobaedream.co.kr/news/2024/09/25/12/1648_1727236205.jpg" alt="ì¤ë§í¸í°ê³¼ ì°¨ëì ê²½ê³ìì´<br>ì¼ì±ì ìÂ·íëì°¨ ìì¡ìë¤"/>
#                             </a>
#                         </div>
#                         <div class="content">
#                             <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews" title="ì¤ë§í¸í°ê³¼ ì°¨ëì ê²½ê³ìì´<br>ì¼ì±ì ìÂ·íëì°¨ ìì¡ìë¤">
#                                 <span class="text">ì¤ë§í¸í°ê³¼ ì°¨ëì ê²½ê³ìì´<br>ì¼ì±ì ìÂ·íëì°¨ ìì¡ìë¤</span>
#                             </a>
#                         </div>
#                     </div>
# <ul class="side-text-list">
#                         <li class="side-text-item">
#                             <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews">
#                                 <span class="text">íëì°¨, ST1 ì¤ììº¡Â·í¹ì¥ íì´í ì¶ìâ¦ì ëí ìì©ë¼ì¸ì ìì±</span>
#                             </a>
#                         </li>
#
#                         <li class="side-text-item">
#                             <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews">
#                                 <span class="text">íëê¸ë¡ë¹ì¤Â·BYD, ìì±ì°¨ í´ìì´ì¡ íë ¥â¦"è»ì´ë°ì  ê³µëíì©"</span>
#                             </a>
#                         </li>
#
#                         <li class="side-text-item">
#                             <a class="link" href="https://www.bobaedream.co.kr/list?code=nnews">
#                                 <span class="text">íëì°¨Â·ê¸°ì ë± 13ê° ì°¨ì¢ 91ë§7ì²547ë ìë°ì  ìì ì¡°ì¹</span>
#                             </a>
#                         </li>
#                     </ul>
#
#
#                 </div>
#             </div>
#
#             <div class="side-section issue">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-issue">íì ì ë¸ë°ìì</span>
#                     </h2>
#                     <a class="link" href="https://www.bobaedream.co.kr/list?code=accident" title="ë¸ëë°ì¤ìì ëë³´ê¸°">
#                         <span class="text">ëë³´ê¸°</span>
#                     </a>
#                 </div>
#                 <div class="issue-content">
#
#                         <div class="issue-list-wrapper">
#                             <ul class="issue-list" id='hot_com'>
#                             </ul>
#                         </div>
#                 </div>
#             </div>
#
#             <div class="side-section notice">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-notice">ê³µì§ì¬í­</span>
#                     </h2>
#                     <a class="link" href="https://www.bobaedream.co.kr/list.php?code=event_notice" title="ê³µì§ì¬í­ ëë³´ê¸°">
#                         <span class="text">ëë³´ê¸°</span>
#                     </a>
#                 </div>
#                 <div class="notice-content">
#                     <ul class="side-text-list" id="notice_main">
#                     </ul>
#                 </div>
#             </div>
#
#             <div class="side-section news">
#                 <div class="section-header">
#                     <h2 class="title">
#                         <span class="title-main-guide">ë§¤ë§¤ê°ì´ë</span>
#                     </h2>
#                     <a class="link" href="https://www.bobaedream.co.kr/dealguide/market_price_new.php" title="ë§¤ë§¤ê°ì´ë ëë³´ê¸°">
#                         <span class="text">ëë³´ê¸°</span>
#                     </a>
#                 </div>
#                 <div class="service-content">
#                     <ul class="service-list">
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/market_price_new.php" class="link" title="ì¤ê³ ì°¨ìì¸">
#                                 <span class="service-01">ì¤ê³ ì°¨ìì¸</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/carinfo.php" class="link" title="ì ì/ìµì/ê°ê²©">
#                                 <span class="service-02">ì ì/ìµì/ê°ê²©</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/false_advertising_new.php" class="link" title="íìë§¤ë¬¼êµ¬ë³">
#                                 <span class="service-03">íìë§¤ë¬¼êµ¬ë³</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/required_documents_new.php" class="link" title="ë§¤ë§¤ìë¥">
#                                 <span class="service-04">ë§¤ë§¤ìë¥</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/Calculation_A.php" class="link" title="ì´ì ë¹ê³ì°">
#                                 <span class="service-05">ì´ì ë¹ê³ì°</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/Calculation_C.php" class="link" title="í ë¶/ë¦¬ì¤ê³ì°">
#                                 <span class="service-06">í ë¶/ë¦¬ì¤ê³ì°</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/Calculation_B.php" class="link" title="ìëì°¨ì¸ê³ì°">
#                                 <span class="service-07">ìëì°¨ì¸ê³ì°</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/Calculation_D.php" class="link" title="ë³´íë£ê³ì°">
#                                 <span class="service-08">ë³´íë£ê³ì°</span>
#                             </a>
#                         </li>
#                         <li class="service-item">
#                             <a href="https://www.bobaedream.co.kr/dealguide/Calculation_E.php" class="link" title="ì ì§ë¹ê³ì°">
#                                 <span class="service-09">ì ì§ë¹ê³ì°</span>
#                             </a>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#
#         </div>
#         <!-- // [E] Main right Contents -->
#         <!-- [S] main-ad-area : ê´ê³ ìì­ -->
# 	<script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   $(function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   });
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/77987245/PCë©ì¸160', [160, 600], 'div-gpt-ad-1465292021799-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
#
# <div class="main-ad-area">
# 	<div class="ad-container" id='div-gpt-ad-1465292021799-0'>
# 	<script type='text/javascript'>
# 	googletag.cmd.push(function() { googletag.display('div-gpt-ad-1465292021799-0'); });
# 	</script>
# 	</div>
# </div>
#
#         <!-- //[E] main-ad-area -->
#     </div>
#
# </div>
# <!-- // bobaeMain -->
#
#
# <!-- [S] bobae-bottom -->
# <div class="bobae-bottom mode-trisection">
#     <div class="component">
#         <div class="btm-article customer">
#             <h2><span class="sp-btm t1">ê³ ê°ì¼í°</span></h2>
#             <div class="cont">
#                 <dl>
#                     <dt><span class="sp-btm cs-call">02-784-2329</span></dt>
#                     <dd><span class="t">íì¼</span>ì¤ì  9ì ~ ì¤í 6ì</dd>
#                     <dd><span class="t">í ìì¼</span>ì¤ì  9ì ~ ì¤í 3ì</dd>
#                 </dl>
#             </div>
#         </div>
#         <div class="btm-article app">
#             <h2><span class="sp-btm t2">ë³´ë°°ëë¦¼ ì± ì¤ì¹íê¸°</span></h2>
#             <div class="clearfix">
#                 <a title="êµ¬ê¸íë ì´ë¡ ì´ë - ìì°½" target="_blank" href="https://play.google.com/store/apps/details?id=co.kr.bobaedream">
#                     <span class="sp-btm app-g">êµ¬ê¸íë ì´</span>
#                 </a>
#                 <a title="ì±ì¤í ì´ë¡ ì´ë - ìì°½" target="_blank" href="https://itunes.apple.com/kr/app/%EB%B3%B4%EB%B0%B0%EB%93%9C%EB%A6%BC-%EA%B5%AD%EB%82%B41%EC%9C%84-%EC%A4%91%EA%B3%A0%EC%B0%A8-%EC%9E%90%EB%8F%99%EC%B0%A8%EC%87%BC%ED%95%91%EB%AA%B0/id496444795?mt=8">
#                     <span class="sp-btm app-a">ì±ì¤í ì´</span>
#                 </a>
#             </div>
#         </div>
#         <div class="btm-article sns">
#             <h2><span class="sp-btm t3">ë³´ë°°ëë¦¼ SNS ì¹ì¶íê¸°</span></h2>
#             <div class="clearfix">
#                 <a target="_blank" title="ë³´ë°°ëë¦¼ íì´ì¤ë¶ ë°ë¡ê°ê¸° - ìì°½" href="https://www.facebook.com/bobaedream" >
#                     <span class="sp-btm sns-facebook">íì´ì¤ë¶</span>
#                 </a>
#                 <a target="_blank" title="ë³´ë°°ëë¦¼ ì¸ì¤íê·¸ë¨ ë°ë¡ê°ê¸° - ìì°½" href="https://www.instagram.com/bobaedream/" >
#                     <span class="sp-btm sns-insta">ì¸ì¤íê·¸ë¨</span>
#                 </a>
#                 <a target="_blank" title="ë³´ë°°ëë¦¼ ì íë¸ ë°ë¡ê°ê¸° - ìì°½" href="https://www.youtube.com/channel/UCLwH6qjWELskt7sGT2b3FOg" >
#                     <span class="sp-btm sns-youtube">ì íë¸</span>
#                 </a>
#                 <a target="_blank" title="ë³´ë°°ëë¦¼ ë¤ì´ë² í¬ì¤í¸ ë°ë¡ê°ê¸° - ìì°½" href="https://post.naver.com/bobae_dream" >
#                     <span class="sp-btm sns-post">ë¤ì´ë² í¬ì¤í¸</span>
#                 </a>
#                 <a target="_blank" title="ë³´ë°°ëë¦¼ ë¤ì´ë² ë¸ë¡ê·¸ ë°ë¡ê°ê¸° - ìì°½" href="http://blog.naver.com/bobae_dream" >
#                     <span class="sp-btm sns-blog">ë¤ì´ë² ë¸ë¡ê·¸</span>
#                 </a>
#             </div>
#         </div>
#         <div class="btm-article family">
#             <h2><span class="sp-btm t4">í¨ë°ë¦¬ ì¬ì´í¸</span></h2>
#             <ul class="clearfix">
#                 <li>
#                     <a title="ë³´ë°°ëë¦¼ ì¤í ë°ì´ íì´ì§ë¡ ì´ë - ìì°½" target="_blank" href="/link">
#                         <span class="sp-btm family-bike">ì¤í ë°ì´ ìì´ì½</span>
#                         <span class="txt">ì¤í ë°ì´</span>
#                     </a>
#                 </li>
#                 <li>
#                     <a title="ë³´ë°°ëë¦¼ íë¬¼í¹ì¥ì°¨ íì´ì§ë¡ ì´ë - ìì°½" target="_blank" href="/link">
#                         <span class="sp-btm family-truck">íë¬¼í¹ì¥ì°¨ ìì´ì½</span>
#                         <span class="txt">íë¬¼í¹ì¥ì°¨</span>
#                     </a>
#                 </li>
#                 <li>
#                     <a title="ë³´ë°°ëë¦¼ ìº íì¹´ íì´ì§ë¡ ì´ë - ìì°½" target="_blank" href="/link">
#                         <span class="sp-btm family-comping">ìº íì¹´ ìì´ì½</span>
#                         <span class="txt">ìº íì¹´</span>
#                     </a>
#                 </li>
#             </ul>
#         </div>
#     </div>
# </div>
# <!-- //[E] bobae-bottom -->
# <!-- bobaeFoot -->
# <div id="bobaeFoot">
#     <div class="bobae-foot">
#         <div class="component">
#             <ul class="policy">
#                 <li><a href="https://www.bobaedream.co.kr/company/company_intro.php">íì¬ìê°</a></li>
#                 <li><a href="https://www.bobaedream.co.kr/center/advertising.html">ì í´/ê´ê³ ë¬¸ì</a></li>
#                 <li><a href="https://www.bobaedream.co.kr/center/recruit.htm">ì¸ì¬ì±ì©</a></li>
#                 <li><a href="https://www.bobaedream.co.kr/company/service.php">ì´ì©ì½ê´</a></li>
#                 <li><a href="/center/error_list.htm">ì ê³ ì¼í°</a></li>
#                 <li><a href="https://www.bobaedream.co.kr/center/center.htm">ê³ ê°ì¼í°</a></li>
# 				<li><a href="https://www.bobaedream.co.kr/company/company_protect_youth.php">ì²­ìëë³´í¸ì ì±</a></li>
#                 <li><a href="https://www.bobaedream.co.kr/company/company_privacy.php"><b>ê°ì¸ì ë³´ì·¨ê¸ë°©ì¹¨</b></a></li>
#                 <li><a href="http://cs1472.com/customer/" target="ìì°½-ìê²©ì§ì"><span class="assistance">ìê²©ì§ì</span></a></li>
#             </ul>
#             <address class="address">
#                 <dl>
#                     <dt>ê³ ê°ì¼í° :</dt>
#                     <dd>02-784-2329</dd>
#                     <dt>í©ì¤ :</dt>
#                     <dd>02-6499-2329</dd>
#                     <dt>ë©ì¼</dt>
#                     <dd><a href="mailto:bobaedream@bobaedream.co.kr" title="ë©ì¼ë³´ë´ê¸°">bobaedream@bobaedream.co.kr</a></dd>
#                     <dt class="blind">ì£¼ì</dt>
#                     <dd>(07995) ìì¸ ìì²êµ¬ ëª©ëëë¡ 233-1 ëë¦¼íì 11, 12ì¸µ</dd>
#                 </dl>
#                 <dl>
#                     <dt>ì¬ììë±ë¡ë²í¸</dt>
#                     <dd><a href="http://www.ftc.go.kr/www/bizCommView.do?key=232&apv_perm_no=2013314011430200466&pageUnit=10&searchCnd=wrkr_no&searchKrwd=1178164543&pageIndex=1" target="_blink"><u>117-81-64543</u></a></dd>
#                     <dt>íµì íë§¤ìì ê³ ë²í¸ : </dt>
#                     <dd>ì 2013-ìì¸ìì²-0465í¸</dd>
#                     <dt>ëíì´ì¬ : </dt>
#                     <dd>ê¹ë³´ë°°</dd>
#                     <dt>ê°ì¸ì ë³´ê´ë¦¬ì±ìì : </dt>
#                     <dd>ì´ìí¸</dd>
#                     <dd>Copyright â (ì£¼)ë³´ë°°ë¤í¸ìí¬</dd>
#                 </dl>
#             </address>
#         </div>
#     </div>
# </div>
# <!-- // bobaeFoot -->
# <div id="dim" class="js-dim"></div>
#
# <script type="text/javascript" src="//image.bobaedream.co.kr/renew2017/assets/js/bobae.comm.js?v=3"></script>
# <script type="text/javascript" src="//image.bobaedream.co.kr/renew2017/assets/js/bobae.main.2019.js?v=191216"></script>
#
# <script>
# 	function special() {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/special_2019.php?dummy=" + dummy;
#
# 			$("#special-spot").load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	function newprd(tid) {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/get_newprd_new_2019.php?dummy=" + dummy + "&tid=" + tid;
#
# 			$("#"+tid).load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	function Communibest(p) {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/Communibest_new_2019.php?dummy=" + dummy + "&p=" + p;
#
# 			$("#Communibest").load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	function notice() {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/notice_main_new_2019.php?dummy=" + dummy;
#
# 			$("#notice_main").load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	function Product(p,n) {
#
# 		if(n) {
# 			$('.hashtag-item').removeClass('is-selected');
# 			$('.hashtag-item').eq(n).addClass('is-selected');
# 		}
#
# 		if(p) {
# 			var dummy = new Date().getTime();
# 			var url = "/script/Product_2019.php?dummy=" + dummy + "&p=" + p;
#
# 				$("#product-spot").load(url,function(response, status, xhr) {
#
# 				});
# 		}
# 	}
#
# 	// ìë¦¼
# 	function get_top_cnt() {
# 	  var dummy     = new Date().getTime();
#
# 	  // , data: "dummy=" + dummy + "&no=" + no + "&dep=" + dep
#
# 	  $.ajax({
# 	    type: 'get'
# 	    , async: true
# 	    , url: '/script/note_get_cnt_new.php'
# 	    , data: "dummy="     + dummy
# 	    , dataType: 'json'
# 	    , beforeSend: function() {
# 	      //$('#ajax_load_indicator').show().fadeIn('fast');
# 	    }
# 	    , success: function(data) {
# 	      var response = data;
#
# 	      $("#noti").html(response['noti']);
# 	    }
# 	    , error: function(data, status, err) {
# 	      //alert('ìë²ìì íµì ì´ ì¤í¨íìµëë¤.' + err);
# 	    }
# 	    , complete: function() {
# 	      //$('#ajax_load_indicator').fadeOut();
# 	    }
# 	  });
# 	}
#
# 	function getnoti() {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/getnoti_2019.php?dummy=" + dummy;
#
# 			$("#svc-noti").load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	function hot_com() {
#
# 		var dummy = new Date().getTime();
# 		var url = "/script/hot_com_2019.php?dummy=" + dummy;
#
# 			$("#hot_com").load(url,function(response, status, xhr) {
#
# 			});
# 	}
#
# 	special();
# 	newprd('cntprd');
# 	Communibest('1_10');
# 	notice();
# 	Product('RD','');
# 	hot_com();
#
# 	if (chkLogin == "yes") {
# 		  get_top_cnt();
# 	}
#
# </script>
#
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-F5YV62DJXL"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-F5YV62DJXL');
# </script>
#
# </body>
# </html>

# %%
url = "https://finance.naver.com/marketindex/"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
el = soup.select('#exchangeList > li')
len(el)
# Out:
# 4

# %%
for el2 in el:
    print(el)
    break
# Out:
# [<li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,328.70</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 9.80</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.09.26 11:24</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">211</span>회</span>
# </div>
# </li>, <li class="">
# <a class="head jpy" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
# <div class="head_info point_dn">
# <span class="value">917.45</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 6.90</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.09.26 11:24</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">211</span>회</span>
# </div>
# </li>, <li class="">
# <a class="head eur" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,480.24</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 9.18</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.09.26 11:24</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">211</span>회</span>
# </div>
# </li>, <li class="">
# <a class="head cny" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
# <div class="head_info point_dn">
# <span class="value">189.25</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.08</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.09.26 11:24</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">211</span>회</span>
# </div>
# </li>]

# %% [markdown]
# # xpath(XML Path Language)
# - XML 이나 HTML 의 특정 요소를 선택할때 사용
# - xpath 사용법
#     - `//` 로 시작해야 함
#         - 하위 모든 엘리먼트를 찾겠다는 의미
#         - `'div a'` => `'//div//a'`
#     -  `/` : 바로 하위 엘리먼트를 찾겠다는 의미.
#         - `'div > a'` => `'//div/a'`
#     -  `*` : 모든 태그라는 의미
#         - `'div > *'` => `'//div/*'`
#     -  `[@id="idname"]`
#         - `id`가 `idname`인 엘리먼트
#     - `div[3]`
#         - 같은 레벨의 div 태그중 에서 3 번째 엘리먼트를 선택
#         - 1부터 시작
#
# - lxml 라이브러리를 이용하면 xpath 로 접근 가능
# - 설치
#
# ```bash
# pip install lxml
# ```

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.3.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.8 kB)
# Downloading lxml-5.3.0-cp310-cp310-macosx_10_9_universal2.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from lxml.html import fromstring

# %%
xpath_obj = fromstring(html_str)
xpath_obj
# Out:
# <Element html at 0x118b66cf0>

# %%
el = xpath_obj.xpath('//html/title') # html > title
el
# Out:
# []

# %%
el[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 el[0].text
#
# IndexError: list index out of range

# %%
xpath_obj.xpath('//div[@class="box"]')
# Out:
# [<Element div at 0x118b6b100>,
#  <Element div at 0x118b684f0>,
#  <Element div at 0x118b68b80>,
#  <Element div at 0x118b6b510>]

# %%
xpath_obj.xpath('//a[@id="css-doc-link"]')
# Out:
# [<Element a at 0x118a7a980>]

# %% [markdown]
# - 요소의 속성값들을 가져오기

# %%
el[0].attrib
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 el[0].attrib
#
# IndexError: list index out of range

# %%
xpath_obj.xpath('//ul/li[3]')[0].text
# Out:
# '사이킷런'

# %%
# %pip install fake_useragent
# Out:
# Collecting fake_useragent
#   Downloading fake_useragent-1.5.1-py3-none-any.whl.metadata (15 kB)
# Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: fake_useragent
# Successfully installed fake_useragent-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from fake_useragent import UserAgent

# %%
ua = UserAgent()

# %%
ua.random
# Out:
# 'Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Mobile/15E148 Safari/604.1 OPX/2.1.0'

# %%
headers = {"User-Agent" : ua.random}
url = 'https://onoffmix.com'
res = requests.get(url)

# %%
ua = UserAgent()
headers = {"user-agent": ua.random}
url= "https://news.naver.com/main/ranking/popularDay.naver"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
#     <meta charset="euc-kr">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="referrer" contents="always">
#     <meta http-equiv="refresh" content="600"/>
#     <meta name="viewport" content="width=1106"/>
#     <meta name="format-detection" content="telephone=no"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/home.naver">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
#
#
#     <title>랭킹뉴스 : 네이버 뉴스</title>
#     <link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='tvh';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.ranking';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness=3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
# var gnb_item_hide_option=128;
#
# var gnb_timestamp = "Thu Sep 26 12:46:41 KST 2024";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
#
# </head>
# <body>
# <div id="wrap">
#     <!-- 광고적용 태그 추가 -->
#     <div id="da_base"></div>
#     <div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
#
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li><a href="/section/100" class="nclicks(lnb.pol)"><span class="tx">정치</span> </a></li>
# 				<li><a href="/section/101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/section/102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/section/103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/section/105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/section/104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li class="on"><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> <span class="blind">선택됨</span></a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/factcheck/main" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
# 				<li><a href="https://media.naver.com/algorithm" class="nclicks(lnb.algo)"><span class="tx">알고리즘 안내</span> </a></li>
# 				<li><a href="/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(lnb.correct)"><span class="tx">정정보도 모음</span> </a></li>
# 			</ul>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>09</strong>.<strong>26</strong><span class="day">(목)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
#     <hr>
#
#     <div class="rankingnews _popularWelBase _persist">
#         <div class="rankingnews_head">
#     <h2 class="rankingnews_tit">언론사별 <em>랭킹뉴스</em></h2>
#     <ul class="rankingnews_tab">
#         <li class="rankingnews_tab_item nclicks('RBP.rnk')  is_selected"><a href="/main/ranking/popularDay.naver">많이 본 뉴스</a><span class="blind">선택됨</span></li>
#         <li class="rankingnews_tab_item nclicks('RBP.cmt') "><a href="/main/ranking/popularMemo.naver">댓글 많은 뉴스</a></li>
#     </ul>
#
#
#
#
#         <button type="button" class="button_rankingnews_info _infoButton nclicks('RBP.inf')">집계안내</button>
#         <div class="rankingnews_info_layer _infoLayer" style="display: none">오전 11시~정오까지 집계한 결과입니다.<br>각 언론사의 모바일 구독자수 비중이 순서에 반영됩니다.<button type="button" class="rankingnews_info_layer_close _infoCloseButton nclicks('RBP.infclose')"><span>닫기</span></button></div>
#
#
#
# </div>
#
#
#
#
#
#
#
#
#
#
# <div class="rankingnews_box_wrap _popularRanking">
#
#
#     <div class="_officeCard _officeCard0" style="display: block">
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/014/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/12/23/logo_014_56_20201223183322.png" width="26" height="26" alt="파이낸셜뉴스"></span>
#                 <strong class="rankingnews_name">파이낸셜뉴스</strong>
#
#                 <p class="rankingnews_tooltip _infoTooltip" style="display:block;">랭킹 결과를 더 볼 수 있어요.</p>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/014/0005245511?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">백종원이 반했던 그 돈가스 가게, 결국 '사고쳤다'</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/014/0005245511?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/014/2024/09/26/5245511.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/014/0005245652?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">‘마약도 음주도 아닌데’ 알몸에 우산만 쓰고 거리 배회한 男 [영상]</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/014/0005245652?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/014/2024/09/26/5245652.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/014/0005245218?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">넷플릭스 '무도실무관'·'흑백요리사' 글로벌 부문별 1위</a>
#                         <span class="list_time ">21시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article
ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“성북동 집 앞에 서 있었다” 빈지노, 30대女에 ‘깜놀’…스토킹 혐의 경찰 수사</a>
#                         <span class="list_time ">1시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370375?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370375.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370334?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“아빠가 허락” 여중생 말 믿고 ‘84만원’ 붙임머리 해준 미용실...부모 “환불 안되면 소송”</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370334?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370334.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370293?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“국세청 공무원도 틀려, 국민은 오죽하겠나”…연말정산 5년간 최소 1조7천억 추가 납세</a>
#                         <span class="list_time ">4시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370293?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370293.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/437/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2023/07/17/logo_437_56_20230717153920.png" width="26" height="26" alt="JTBC"></span>
#                 <strong class="rankingnews_name">JTBC</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411807?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">머리는 말, 몸통은 물고기?…호주서 산 채로 잡힌 '거대 산갈치'</a>
#                         <span class="list_time ">15시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411807?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/25/411807.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411817?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"이러다 김건희 빠지고 우리만 달린다"…주가조작 주포, 도피 중 쓴 편지</a>
#                         <span class="list_time ">4시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411817?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/26/411817.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
# ...
#                         <span class="list_time ">1일전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/665/0000003728?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/665/2024/09/24/3728.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/145/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img data-src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="26" height="26" alt="레이디경향"></span>
#                 <strong class="rankingnews_name">레이디경향</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">특별한 식단·운동 없이…혈압 낮추는 20가지 방법</a>
#                         <span class="list_time ">1시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21187.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">소득 증가율 12.6%…전문직 1위 수의사</a>
#                         <span class="list_time ">1시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21188.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">‘주우재 패딩’ 몽벨, 최대 20% 할인 팝업스토어 개장</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21186.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">때가 됐다, 가을 낭만 가득한 특급호텔 와인 축제 4</a>
#                         <span class="list_time ">22시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/25/21185.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021184?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">나를 살찌우는 가을, 아니 ‘달걀 푸딩’[펀펀(funfun)한 요리]</a>
#                         <span class="list_time ">1일전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021184?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/25/21184.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#     </div>
#
#
#
#
#
# <button type="button" class="button_rankingnews_more _moreButton nclicks('RBP.more')">다른 언론사 랭킹 더보기</button>
#
# <a href="https://news.naver.com/main/ombudsman/rankingHelp.naver?mid=omb" class="link_rankingnews_info nclicks('RBP.policy')">랭킹 뉴스 집계 기준</a>
#
# <ul class="rankingnews_date">
#
#     <li class="is_selected"><a href="/main/ranking/popularDay.naver?date=20240926" class="nclicks('RBP.date')">09월 26일(목)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240925" class="nclicks('RBP.date')">09월 25일(수)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240924" class="nclicks('RBP.date')">09월 24일(화)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240923" class="nclicks('RBP.date')">09월 23일(월)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240922" class="nclicks('RBP.date')">09월 22일(일)</a></li>
#
# </ul>
#
# <script type="text/javascript">
#     var PopularRankingManager = jindo.$Class({
#         $static: {
#             RANKING_LIST_SELECTOR: '._officeCard',
#             MORE_BUTTON_SELECTOR: '._moreButton',
#             INFO_BUTTON_SELECTOR: '._infoButton',
#             INFO_LAYER_SELECTOR: '._infoLayer',
#             INFO_CLOSE_BUTTON_SELECTOR: '._infoCloseButton',
#             INFO_TOOLTIP_SELECTOR : '._infoTooltip',
#             COOKIE_NAME_DISPLAY_INFO : 'pc_ranking_info',
#             COOKIE_VALUE_DISPLAY_INFO : 'Y'
#         },
#
#         $init: function(base) {
#             // persist restore
#             var persistHtml = Persist.getPersistedData('persist-ranking-data');
#             if (persistHtml) {
#                 jindo.$$.getSingle('._persist').innerHTML = persistHtml;
#             }
#             var persistScrollTop = Persist.getPersistedData('persist-ranking-scroll-top');
#             if (persistScrollTop) {
#                 window.scrollTo(0, persistScrollTop); // 스크롤 위치 복구
#             }
#
#             this._welBase = jindo.$Element(base);
#             this._popularRanking = jindo.$Element(this._welBase.query("._popularRanking"));
#             this._officeRankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#             this._moreButton = jindo.$Element(this._welBase.query(this.constructor.MORE_BUTTON_SELECTOR));
#             this._infoLayer = jindo.$Element(this._welBase.query(this.constructor.INFO_LAYER_SELECTOR));
#             this._infoTooltip = jindo.$Element(this._welBase.query(this.constructor.INFO_TOOLTIP_SELECTOR));
#
#             // cookie
#             this._cookieLifeDay = 1095;
#             this._cookie = jindo.$Cookie();
#
#             this._setInfoTooltipAction();
#
#             // persist save
#             Persist.addOnClickLinkListener(function(persistModel) {
#                 var persistTargetHtml = jindo.$$.getSingle('._persist').innerHTML;
#                 persistModel.set('persist-ranking-data', persistTargetHtml); // 컨텐츠 내용 저장
#                 persistModel.set('persist-ranking-scroll-top', jindo.$Document().scrollPosition().top); // 스크롤 위치 저장
#             });
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate("click", this.constructor.MORE_BUTTON_SELECTOR, jindo.$Fn(this._showMoreOfficeRanking, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_CLOSE_BUTTON_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#         },
#
#         _setInfoTooltipAction: function() {
#             var that = this;
#
#             setTimeout(function () {
#                 that._infoTooltip.hide();
#                 that._infoTooltip = null;
#             }, 5000);
#
#             this._saveCookie(this.constructor.COOKIE_NAME_DISPLAY_INFO, this.constructor.COOKIE_VALUE_DISPLAY_INFO);
#         },
#
#         _showMoreOfficeRanking: function(event) {
#             event.stopDefault();
#
#             var arrayLength = this._officeRankingListArray.length();
#             for (var i=0 ; i < arrayLength ; i++) {
#                 var rankingList = this._officeRankingListArray.get(i);
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._officeRankingListArray.length()) {
#                         break;
#                     }
#
#                     var nextRankingList = this._officeRankingListArray.get(nextIndex);
#
#                     if (nextRankingList.visible() === false) {
#                         this._loadLazyImage(nextRankingList);
#                         this._popularRanking.append(nextRankingList);
#                         nextRankingList.show();
#
#                         if (nextIndex == (arrayLength - 1)) {
#                             this._moreButton.hide();
#                         }
#                         break;
#                     }
#                 }
#             }
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.hide();
#         },
#
#         _loadLazyImage: function(targetList) {
#             jindo.$A(targetList.queryAll("img")).forEach(function(img){
#                 var welImg = jindo.$Element(img);
#                 var src = welImg.attr("data-src");
#                 if (src) {
#                     welImg
#                         .attr("src", src)
#                         .attr('data-src', null);
#                 }
#             });
#         },
#
#         _saveCookie : function(name, value) {
#             this._cookie.remove(name, '.naver.com', '/');
#             this._cookie.set(name, value, this._cookieLifeDay);
#         },
#
#         _getCookie : function(name) {
#             return this._cookie.get(name);
#         }
#     });
#
#     window.addEventListener("load", function() {
#         if (jindo.$$.getSingle("._popularRanking")) {
#             var popularWelBase = jindo.$$.getSingle("._popularWelBase");
#             new PopularRankingManager(popularWelBase);
#         }
#     });
# </script>
#     </div>
#
#     <hr>
#
#
#
# <hr>
# <div id="mp_footer" class="mp_footer">
#     <div class="mp_footer_inner">
#
# <div class="floating_btn" >
#     <div class="floating_inner">
#         <a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
#         <a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
#     </div>
# </div>
#
#
# <ul class="mp_footer_list">
#
#
#
#
#             <li class="mp_footer_item"><a href="https://nid.naver.com/nidlogin.login" class="mp_footer_a nclicks(fot.login)">로그인</a></li>
#
#
#     <li class="mp_footer_item"><a href="https://www.naver.com/more.html" class="mp_footer_a nclicks(fot.serviceall)">전체서비스</a></li>
#     <li class="mp_footer_item"><a href="/main/ombudsman/index.naver" class="mp_footer_a nclicks(fot.guide)">서비스안내</a></li>
#     <li class="mp_footer_item"><a href="https://help.naver.com/alias/news/news_001.naver" class="mp_footer_a nclicks(fot.report)">오류신고</a></li>
#     <li class="mp_footer_item"><a href="https://help.naver.com/alias/news/news_007.naver" class="mp_footer_a nclicks(fot.help)">고객센터</a></li>
#
#     <li class="mp_footer_item"><a href="/main/ombudsman/edit.naver?mid=omb" class="mp_footer_charge nclicks(fot.editor)">기사배열 원칙 책임자 : 김수향</a></li>
#
#     <li class="mp_footer_item"><span class="mp_footer_charge">청소년 보호 책임자 : 이정규</span></li>
# </ul>
#
#         <p class="mp_footer_copyright">이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
#
#
#         <div class="mp_footer_naverlogo"><a href="https://www.navercorp.com/" class="mp_footer_naverlogo_a nclicks(fot.navercorp)">NAVER</a></div>
#
#         <!-- -->
#
#
#     </div>
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         NeloSender.init({
#             neloCollectorUrl: "https://kr-col-ext.nelo.navercorp.com/_store",
#             projectName: "P638fcb_news-front",
#             host: "real"
#         });
#     })();
#
#
#     (function () {
#         news.right.RightSideFloatingManager.init();
#     })();
#
#
#
#     (function () {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     new news.util.Calendar({
#         url: '/main/ranking/popularDay?mid=etc&date=',
#
#         selectedDate: '//',
#         minDate: '//',
#         maxDate: '//'
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         window.ntm_news = window.ntm_news || [];
#
#         jindo.$Fn(function () {
#             var ntmUrl = 'https://ntm.pstatic.net/scripts/ntm_b7032129a433.js';
#
#
#
#             ntmInit(ntmUrl);
#         }).attach(window, "load");
#
#
#         var eventType = "onpageshow" in window ? "pageshow" : "load";
#         jindo.$Fn(function () {
#             var gdid = '';
#
#
#
#             ntmCustomPageViewSend({
#                 sti: '',
#                 gdid: gdid
#             })
#         }).attach(window, eventType);
#
#     })();
#
#
#
#
#
#
#     news.startup();
#
#
#     jindo.$Fn(function () {
#         var welSkip = jindo.$Element("u_skip");
#         if (welSkip === null) {
#             return;
#         }
#         welSkip.delegate("click", "a", function (weEvent) {
#             weEvent.stopDefault();
#             var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#             oWebAccessibilityUtil.moveFocus(elTarget);
#         });
#     }).attach(window, "load");
#
#
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
# </script>
#
# </div>
# </body>
# </html>

# %%
html_res = res.text

# %%
soup = BeautifulSoup(html_res, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="telephone=no" name="format-detection">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <title>랭킹뉴스 : 네이버 뉴스</title>
# <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='tvh';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.ranking';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness=3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
# var gnb_item_hide_option=128;
#
# var gnb_timestamp = "Thu Sep 26 12:46:41 KST 2024";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/section/100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/section/101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/section/102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/section/103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/section/105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/section/104"><span class="tx">세계</span> </a></li>
# <li class="on"><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/factcheck/main"><span class="tx">팩트체크</span> </a></li>
# <li><a class="nclicks(lnb.algo)" href="https://media.naver.com/algorithm"><span class="tx">알고리즘 안내</span> </a></li>
# <li><a class="nclicks(lnb.correct)" href="/main/ombudsman/revisionArticleList.naver?mid=omb"><span class="tx">정정보도 모음</span> </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>09</strong>.<strong>26</strong><span class="day">(목)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <div class="rankingnews _popularWelBase _persist">
# <div class="rankingnews_head">
# <h2 class="rankingnews_tit">언론사별 <em>랭킹뉴스</em></h2>
# <ul class="rankingnews_tab">
# <li class="rankingnews_tab_item nclicks('RBP.rnk') is_selected"><a href="/main/ranking/popularDay.naver">많이 본 뉴스</a><span class="blind">선택됨</span></li>
# <li class="rankingnews_tab_item nclicks('RBP.cmt')"><a href="/main/ranking/popularMemo.naver">댓글 많은 뉴스</a></li>
# </ul>
# <button class="button_rankingnews_info _infoButton nclicks('RBP.inf')" type="button">집계안내</button>
# <div class="rankingnews_info_layer _infoLayer" style="display: none">오전 11시~정오까지 집계한 결과입니다.<br/>각 언론사의 모바일 구독자수 비중이 순서에 반영됩니다.<button class="rankingnews_info_layer_close _infoCloseButton nclicks('RBP.infclose')" type="button"><span>닫기</span></button></div>
# </div>
# <div class="rankingnews_box_wrap _popularRanking">
# <div class="_officeCard _officeCard0" style="display: block">
# <div class="rankingnews_box">
# <a class="rankingnews_box_head nclicks('RBP.rnkpname')" href="https://media.naver.com/press/014/ranking?type=popular">
# <span class="rankingnews_thumb"><img alt="파이낸셜뉴스" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo
height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">4</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/665/0000003733?ntype=RANKING">너 누구야? 형의 전쟁 [책이 된 웹소설: 회귀가 빙의를 싫어함]</a>
# <span class="list_time">17시간전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/665/0000003733?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/665/2024/09/25/3733.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">5</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/665/0000003728?ntype=RANKING">금값이 금값 된 진짜 이유: 중앙은행 현물 사재기와 바젤Ⅲ</a>
# <span class="list_time">1일전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/665/0000003728?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/665/2024/09/24/3728.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="rankingnews_box">
# <a class="rankingnews_box_head nclicks('RBP.rnkpname')" href="https://media.naver.com/press/145/ranking?type=popular">
# <span class="rankingnews_thumb"><img alt="레이디경향" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" height="26" width="26"/></span>
# <strong class="rankingnews_name">레이디경향</strong>
# </a>
# <ul class="rankingnews_list">
# <li>
# <em class="list_ranking_num">1</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING">특별한 식단·운동 없이…혈압 낮추는 20가지 방법</a>
# <span class="list_time">1시간전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21187.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">2</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING">소득 증가율 12.6%…전문직 1위 수의사</a>
# <span class="list_time">1시간전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21188.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">3</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING">‘주우재 패딩’ 몽벨, 최대 20% 할인 팝업스토어 개장</a>
# <span class="list_time">2시간전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21186.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">4</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING">때가 됐다, 가을 낭만 가득한 특급호텔 와인 축제 4</a>
# <span class="list_time">22시간전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/25/21185.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# <li>
# <em class="list_ranking_num">5</em>
# <div class="list_content">
# <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021184?ntype=RANKING">나를 살찌우는 가을, 아니 ‘달걀 푸딩’[펀펀(funfun)한 요리]</a>
# <span class="list_time">1일전</span>
# </div>
# <a class="list_img nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/145/0000021184?ntype=RANKING">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/25/21184.jpg?type=nf70_70" height="70" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';" width="70"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <button class="button_rankingnews_more _moreButton nclicks('RBP.more')" type="button">다른 언론사 랭킹 더보기</button>
# <a class="link_rankingnews_info nclicks('RBP.policy')" href="https://news.naver.com/main/ombudsman/rankingHelp.naver?mid=omb">랭킹 뉴스 집계 기준</a>
# <ul class="rankingnews_date">
# <li class="is_selected"><a class="nclicks('RBP.date')" href="/main/ranking/popularDay.naver?date=20240926">09월 26일(목)</a></li>
# <li class=""><a class="nclicks('RBP.date')" href="/main/ranking/popularDay.naver?date=20240925">09월 25일(수)</a></li>
# <li class=""><a class="nclicks('RBP.date')" href="/main/ranking/popularDay.naver?date=20240924">09월 24일(화)</a></li>
# <li class=""><a class="nclicks('RBP.date')" href="/main/ranking/popularDay.naver?date=20240923">09월 23일(월)</a></li>
# <li class=""><a class="nclicks('RBP.date')" href="/main/ranking/popularDay.naver?date=20240922">09월 22일(일)</a></li>
# </ul>
# <script type="text/javascript">
#     var PopularRankingManager = jindo.$Class({
#         $static: {
#             RANKING_LIST_SELECTOR: '._officeCard',
#             MORE_BUTTON_SELECTOR: '._moreButton',
#             INFO_BUTTON_SELECTOR: '._infoButton',
#             INFO_LAYER_SELECTOR: '._infoLayer',
#             INFO_CLOSE_BUTTON_SELECTOR: '._infoCloseButton',
#             INFO_TOOLTIP_SELECTOR : '._infoTooltip',
#             COOKIE_NAME_DISPLAY_INFO : 'pc_ranking_info',
#             COOKIE_VALUE_DISPLAY_INFO : 'Y'
#         },
#
#         $init: function(base) {
#             // persist restore
#             var persistHtml = Persist.getPersistedData('persist-ranking-data');
#             if (persistHtml) {
#                 jindo.$$.getSingle('._persist').innerHTML = persistHtml;
#             }
#             var persistScrollTop = Persist.getPersistedData('persist-ranking-scroll-top');
#             if (persistScrollTop) {
#                 window.scrollTo(0, persistScrollTop); // 스크롤 위치 복구
#             }
#
#             this._welBase = jindo.$Element(base);
#             this._popularRanking = jindo.$Element(this._welBase.query("._popularRanking"));
#             this._officeRankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#             this._moreButton = jindo.$Element(this._welBase.query(this.constructor.MORE_BUTTON_SELECTOR));
#             this._infoLayer = jindo.$Element(this._welBase.query(this.constructor.INFO_LAYER_SELECTOR));
#             this._infoTooltip = jindo.$Element(this._welBase.query(this.constructor.INFO_TOOLTIP_SELECTOR));
#
#             // cookie
#             this._cookieLifeDay = 1095;
#             this._cookie = jindo.$Cookie();
#
#             this._setInfoTooltipAction();
#
#             // persist save
#             Persist.addOnClickLinkListener(function(persistModel) {
#                 var persistTargetHtml = jindo.$$.getSingle('._persist').innerHTML;
#                 persistModel.set('persist-ranking-data', persistTargetHtml); // 컨텐츠 내용 저장
#                 persistModel.set('persist-ranking-scroll-top', jindo.$Document().scrollPosition().top); // 스크롤 위치 저장
#             });
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate("click", this.constructor.MORE_BUTTON_SELECTOR, jindo.$Fn(this._showMoreOfficeRanking, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_CLOSE_BUTTON_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#         },
#
#         _setInfoTooltipAction: function() {
#             var that = this;
#
#             setTimeout(function () {
#                 that._infoTooltip.hide();
#                 that._infoTooltip = null;
#             }, 5000);
#
#             this._saveCookie(this.constructor.COOKIE_NAME_DISPLAY_INFO, this.constructor.COOKIE_VALUE_DISPLAY_INFO);
#         },
#
#         _showMoreOfficeRanking: function(event) {
#             event.stopDefault();
#
#             var arrayLength = this._officeRankingListArray.length();
#             for (var i=0 ; i < arrayLength ; i++) {
#                 var rankingList = this._officeRankingListArray.get(i);
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._officeRankingListArray.length()) {
#                         break;
#                     }
#
#                     var nextRankingList = this._officeRankingListArray.get(nextIndex);
#
#                     if (nextRankingList.visible() === false) {
#                         this._loadLazyImage(nextRankingList);
#                         this._popularRanking.append(nextRankingList);
#                         nextRankingList.show();
#
#                         if (nextIndex == (arrayLength - 1)) {
#                             this._moreButton.hide();
#                         }
#                         break;
#                     }
#                 }
#             }
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.hide();
#         },
#
#         _loadLazyImage: function(targetList) {
#             jindo.$A(targetList.queryAll("img")).forEach(function(img){
#                 var welImg = jindo.$Element(img);
#                 var src = welImg.attr("data-src");
#                 if (src) {
#                     welImg
#                         .attr("src", src)
#                         .attr('data-src', null);
#                 }
#             });
#         },
#
#         _saveCookie : function(name, value) {
#             this._cookie.remove(name, '.naver.com', '/');
#             this._cookie.set(name, value, this._cookieLifeDay);
#         },
#
#         _getCookie : function(name) {
#             return this._cookie.get(name);
#         }
#     });
#
#     window.addEventListener("load", function() {
#         if (jindo.$$.getSingle("._popularRanking")) {
#             var popularWelBase = jindo.$$.getSingle("._popularWelBase");
#             new PopularRankingManager(popularWelBase);
#         }
#     });
# </script>
# </div>
# <hr/>
# <hr/>
# <div class="mp_footer" id="mp_footer">
# <div class="mp_footer_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <ul class="mp_footer_list">
# <li class="mp_footer_item"><a class="mp_footer_a nclicks(fot.login)" href="https://nid.naver.com/nidlogin.login">로그인</a></li>
# <li class="mp_footer_item"><a class="mp_footer_a nclicks(fot.serviceall)" href="https://www.naver.com/more.html">전체서비스</a></li>
# <li class="mp_footer_item"><a class="mp_footer_a nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스안내</a></li>
# <li class="mp_footer_item"><a class="mp_footer_a nclicks(fot.report)" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></li>
# <li class="mp_footer_item"><a class="mp_footer_a nclicks(fot.help)" href="https://help.naver.com/alias/news/news_007.naver">고객센터</a></li>
# <li class="mp_footer_item"><a class="mp_footer_charge nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 김수향</a></li>
# <li class="mp_footer_item"><span class="mp_footer_charge">청소년 보호 책임자 : 이정규</span></li>
# </ul>
# <p class="mp_footer_copyright">이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <div class="mp_footer_naverlogo"><a class="mp_footer_naverlogo_a nclicks(fot.navercorp)" href="https://www.navercorp.com/">NAVER</a></div>
# <!-- -->
# </div>
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         NeloSender.init({
#             neloCollectorUrl: "https://kr-col-ext.nelo.navercorp.com/_store",
#             projectName: "P638fcb_news-front",
#             host: "real"
#         });
#     })();
#
#
#     (function () {
#         news.right.RightSideFloatingManager.init();
#     })();
#
#
#
#     (function () {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     new news.util.Calendar({
#         url: '/main/ranking/popularDay?mid=etc&date=',
#
#         selectedDate: '//',
#         minDate: '//',
#         maxDate: '//'
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         window.ntm_news = window.ntm_news || [];
#
#         jindo.$Fn(function () {
#             var ntmUrl = 'https://ntm.pstatic.net/scripts/ntm_b7032129a433.js';
#
#
#
#             ntmInit(ntmUrl);
#         }).attach(window, "load");
#
#
#         var eventType = "onpageshow" in window ? "pageshow" : "load";
#         jindo.$Fn(function () {
#             var gdid = '';
#
#
#
#             ntmCustomPageViewSend({
#                 sti: '',
#                 gdid: gdid
#             })
#         }).attach(window, eventType);
#
#     })();
#
#
#
#
#
#
#     news.startup();
#
#
#     jindo.$Fn(function () {
#         var welSkip = jindo.$Element("u_skip");
#         if (welSkip === null) {
#             return;
#         }
#         welSkip.delegate("click", "a", function (weEvent) {
#             weEvent.stopDefault();
#             var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#             oWebAccessibilityUtil.moveFocus(elTarget);
#         });
#     }).attach(window, "load");
#
#
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
# </script>
# </div>
# </body>
# </html>

# %%
news_box_list = soup.select('._officeCard0  .rankingnews_box')
len(news_box_list)
# Out:
# 12
