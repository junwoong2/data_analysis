# %% [markdown]
# ## 크롤링 예제

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bs4 import BeautifulSoup
#       2 import requests
#       3 from datetime import datetime
#
# ModuleNotFoundError: No module named 'bs4'

# %% [markdown]
# pip install requests

# %%
pip install requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 10.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

print(requests)
# Out:
# <module 'requests' from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/__init__.py'>

# %% [markdown]
# ## requests 모듈

# %% [markdown]
# ### requests.get(url)
# - return : requests.response

# %%
import requests

requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import requests
# ----> 3 requests.get(url)
#
# NameError: name 'url' is not defined

# %%
import requests

url = "http://www.naver.com"
print(requests.get(url))
# Out:
# <Response [200]>

# %% [markdown]
# #### response [200]은 성공을 의미함

# %%
import requests

url = "http://www.naver.com"
response = requests.get(url)

print(response.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %% [markdown]
# ### response.xx
# - url
# - content
# - encoding
# - headers
# - json
# - links
# - ok
# - status_code

# %%
pip install bs4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 6.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.naver.com"
response = requests.get(url)
print(response.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.naver.com"
response = requests.get(url)
# print(response.text)

print(BeautifulSoup(response.text, 'html.parser'))
# Out:
#  <!DOCTYPE html>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net/"
response = requests.get(url)
print(response.text[:])

soup = BeautifulSoup(response.text, 'html.parser')

print(soup.title)
print(soup.title.string)
print(soup.span)
print(soup.findAll('span'))
# Out:
# <!doctype html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8">
#   <title>Daum</title>
#   <meta http-equiv="x-ua-compatible" content="IE=edge">
#   <meta property="og:url" content="https://www.daum.net/">
#   <meta property="og:type" content="website">
#   <meta property="og:title" content="Daum">
#   <meta http-equiv="Pragma" content="no-cache">
#   <meta http-equiv="Expires" content="-1">
#   <meta name="referrer" content="origin">
#   <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
#   <meta property="og:image" content="https://t1.daumcdn.net/daumtop_deco/images/og/og_daum.png">
#   <meta property="og:description" content="ì´ì©ì ì íê¶ì ê°íí ë´ì¤, ì¸ìì ëª¨ë  ì ë³´ë¥¼ ì°ê²°íë ê²ì. Daumìì ëì ê´ì¬ ì½íì¸ ë¥¼ ì¦ê²¨ë³´ì¸ì.">
# ...

# %% [markdown]
# ### html 문서에서 태그를 가져오는 코드
# print(soup.findAll("XX"))

# %%
from bs4 import BeautifulSoup
import requests

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

results = soup.findAll('a','link_favorsch')

for result in results:
    print(result.get_text(),"\n")

# %% [markdown]
# ## 날씨 api 받아서 출력하기

# %%
import requests
import json

lat = "37.566381"
apikey = "b62ff01bc7a9b057281c3a1fac7a1381"
lon = "126.977717"

api = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={apikey}"

result = requests.get(api)
data = json.loads(result.text)

print(data["name"],"의 날씨입니다.")
print("날씨는 ",data["weather"][0]["description"],"입니다.")
print("현재 온도는 ",data["main"]["temp"],"입니다.")
print("하지만 체감 온도는 ",data["main"]["feels_like"],"입니다.")
print("최저 기온은 ",data["main"]["temp_min"],"입니다.")
print("최고 기온은 ",data["main"]["temp_max"],"입니다.")
print("습도는 ",data["main"]["humidity"],"입니다.")
print("기압은 ",data["main"]["pressure"],"입니다.")
print("풍향은 ",data["wind"]["deg"],"입니다.")
print("풍속은 ",data["wind"]["speed"],"입니다.")
# Out:
# Seoul 의 날씨입니다.
# 날씨는  broken clouds 입니다.
# 현재 온도는  305.5 입니다.
# 하지만 체감 온도는  310.42 입니다.
# 최저 기온은  304.99 입니다.
# 최고 기온은  305.97 입니다.
# 습도는  58 입니다.
# 기압은  1014 입니다.
# 풍향은  240 입니다.
# 풍속은  2.06 입니다.

# %%
import requests
import json

lat = "37.566381"
apikey = "b62ff01bc7a9b057281c3a1fac7a1381"
lon = "126.977717"

api = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={apikey}"

print(api)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=37.566381&lon=126.977717&appid=b62ff01bc7a9b057281c3a1fac7a1381

# %% [markdown]
# ## translator을 이용한 번역

# %%
pip install --upgrade googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
#   DEPRECATION: googletrans is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for googletrans ... done
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from googletrans import Translator

translator = Translator()
sentence = input("언어를 감지할 문장을 입력해주세요 : ")
detected = translator.detect(sentence)
print(f"감지된 언어: {detected.lang}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       3 translator = Translator()
#       4 sentence = input("언어를 감지할 문장을 입력해주세요 : ")
# ----> 5 detected = translator.detect(sentence)
#       6 print(f"감지된 언어: {detected.lang}")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/googletrans/client.py:255, in Translator.detect(self, text, **kwargs)
#     252         result.append(lang)
#     253     return result
# --> 255 data = self._translate(text, 'en', 'auto', kwargs)
#     257 # actual source language that will be recognized by Google Translator when the
#     258 # src passed is equal to auto.
#     259 src = ''
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/googletrans/client.py:78, in Translator._translate(self, text, dest, src, override)
# ...

# %%
from googletrans import Translator

translator = Translator()

# sentence = "안녕하세요 코드라이언입니다."
sentence = input("언어를 감지할 문장을 입력해주세요 : ")
detected = translator.detect(sentence)

print(detected.lang)
# Out:
# en

# %%
from googletrans import Translator

translator = Translator()

sentence = "안녕하세요 코드라이언입니다"
detected = translator.detect(sentence)

translated = translator.translate(sentence, "en")

print(detected.lang)
print(translated.dest,":",translated.text)
# Out:
# ko
# en : Hello, this is Code Ryan

# %% [markdown]
# ## 메일보내는 프로그램

# %%
import smtplib

SMTP_SERVER = "smtp.gmail.com"
SMTP_PORT = 465

smtp = smtplib.SMTP_SSL(SMTP_SERVER, SMTP_PORT)

print(smtp.login("wnsdnd0611@gmail.com", "Answnsdnd0611*"))
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[6], line 8
#       4 SMTP_PORT = 465
#       6 smtp = smtplib.SMTP_SSL(SMTP_SERVER, SMTP_PORT)
# ----> 8 print(smtp.login("wnsdnd0611@gmail.com", "Answnsdnd0611*"))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
# ...
