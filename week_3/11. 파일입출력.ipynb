# %% [markdown]
# # 파일 입출력
#
# - open 함수: 파일을 열수 있는 함수, 파일 객체를 반환한다.
# - 파일열기 모드는 대표적으로 다음과 같다.
#     - w: 쓰기 모드
#     - a: 추가 모드
#     - r: 읽기 모드
#
#
#
# - open 함수로 열면 파일 객체가 반환 되는데 파일에 대한 처리가 종료되면 항상 close 메소드를 이용해서 닫아줘야한다.

# %%
DATA_PATH = "data/"

# %%
import os
if not os.path.isdir(f"{DATA_PATH}"):
    os.mkdir(f"{DATA_PATH}")

# %% [markdown]
# - 쓰기 모드

# %%
f = open(f"{DATA_PATH}memo.txt", "w")
print(f)
f.close()
# Out:
# <_io.TextIOWrapper name='data/memo.txt' mode='w' encoding='UTF-8'>

# %%
f = open(f"{DATA_PATH}memo.txt", "w", encoding="utf-8")

for i in range(1,11):
    f.write(f"{i}번째 줄입니다.\n")

f.close()

# %% [markdown]
# - 추가모드

# %%
f = open(f"{DATA_PATH}memo.txt", "a", encoding="utf-8")

f.write(f"11번째 줄입니다.")

f.close()

# %% [markdown]
# - 읽기 모드

# %%
f = open(f"{DATA_PATH}memo.txt", "r", encoding="utf-8")

data = f.read()

f.close()

# %%
print(data)
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.
# 11번째 줄입니다.

# %%
f = open(f"{DATA_PATH}memo.txt", "r", encoding="utf-8")

while True:
    data = f.readline()
    print(data)
    if data == "":
        break

f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.
#
# 11번째 줄입니다.

# %%
f = open(f"{DATA_PATH}memo.txt", "r", encoding="utf-8")

for data in f.readlines():
    print(data)

f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.
#
# 11번째 줄입니다.

# %% [markdown]
# - with 문
#     - 자원을 획득해서 사용 후에 반납할 때 자동으로 반납해줌

# %%
with open(f"{DATA_PATH}memo.txt", "r", encoding = "utf-8") as f:
    data = f.read()

data
# Out:
# '1번째 줄입니다.\n2번째 줄입니다.\n3번째 줄입니다.\n4번째 줄입니다.\n5번째 줄입니다.\n6번째 줄입니다.\n7번째 줄입니다.\n8번째 줄입니다.\n9번째 줄입니다.\n10번째 줄입니다.\n11번째 줄입니다.'

# %% [markdown]
# # JSON(JavaScript Object Notation)
# - 자바스크립트에서 사용되는 객체 표현식
# - 데이터를 저장하거나 전송할때 많이 사용
# - 서버와 클라이언트간의 데이터 전송과정에서 많이 사용
# - 파이썬의 딕셔너리와 매우 유사

# %%
data = {
    "karns" : {
        "age" : 44,
        "phone" : "000-0000-0000",
        "city" : "seoul"
    },
    "daniel" : {
        "age" : 30,
        "phone" : "010-1111-1111"
    }
}

# %% [markdown]
# - json 파일 저장하기

# %%
import json

with open(f"{DATA_PATH}info.json", "w", encoding="utf-8") as f:
    json.dump(data, f)

# %% [markdown]
# - Json 파일 불러오기

# %%
with open(f"{DATA_PATH}info.json", "r", encoding="utf-8") as f:
    data = json.load(f)

type(data)
# Out:
# dict

# %% [markdown]
# ### YAML (Yet Another Markup Language)
# - 사람이 쉽게 읽을 수 있는 데이터 양식
# - 데이터를 저장하거나 전송할때 많이 사용

# %% [markdown]
# ```yaml
# karns:
#     age: 44
#     phone: 010-0000-0000
#     city: seoul
# 관수:
#     age: 30
#     phone: 010-1111-1111
# ```

# %%
pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

# %%
data
# Out:
# {'karns': {'age': 44, 'phone': '000-0000-0000', 'city': 'seoul'},
#  'daniel': {'age': 30, 'phone': '010-1111-1111'}}

# %%
with open(f"{DATA_PATH}info.txt", "w", encoding="utf-8") as f:
    yaml.dump(data, f, allow_unicode=True, indent=4)

# %%
with open(f"{DATA_PATH}info.txt", "r", encoding="utf-8") as f:
    data = yaml.full_load(f)
data
# Out:
# {'daniel': {'age': 30, 'phone': '010-1111-1111'},
#  'karns': {'age': 44, 'city': 'seoul', 'phone': '000-0000-0000'}}

# %% [markdown]
# # pickle 모듈
# - 우리가 사용하는 다양한 객체들을 파일로 저장하고 싶다면?
# - 객체의 구조를 직렬화해서 파일로 저장한다.
# - 보통 딕셔너리, 리스트 등을 저장하고 불러올때 사용한다.

# %%
import pickle

# %%
data = [1,2,3,4,[10,20],"hi"]

# %%
with open(f"{DATA_PATH}data.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
with open(f"{DATA_PATH}data.pkl", "rb") as f:
    lst = pickle.load(f)

lst
# Out:
# [1, 2, 3, 4, [10, 20], 'hi']
